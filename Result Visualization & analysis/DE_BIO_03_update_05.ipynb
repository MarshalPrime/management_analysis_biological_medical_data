# %% [markdown]
# #**Protein Structure complexity Analysis**

# %% [markdown]
# ##**1. Introduction**

# %% [markdown]
# Explain Data
#
# **Complexity calculation features**
# *   Shannon entropy
# *   Number of transitions
# *   Fractal Dimension
#
# **Biological features**
#
# *   Enzymes
# *   Transcription Factor

# %% [markdown]
# ##**2. Data Preprocessing**

# %% [markdown]
# **To add further**
#
# 1. Enzymes and Transcription Factors Mean, std, min,max - draw together and see the comparison

# %% [markdown]
# ##**Import the Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##**Load the dataset**

# %%
df = pd.read_csv("File_TFs.csv")

# %%
Df = pd.read_csv("File_enzymes.csv")

# %%
df.head()
# Out:
#       TF_ID  Shannon Entropy  Number of Transitions  Fractal Dimension
# 0   P22736          1.400063                     76           1.625714
# 1   Q9H334          1.340514                     70           1.658552
# 2   P48436          1.480286                     68           1.531153
# 3   P28347          1.358966                     64           1.640730
# 4   Q06330          1.494394                     75           1.713782

# %%
Df.head()
# Out:
#   Enzyme_ID  Shannon_Entropy  Number_of_Transitions  Fractal_Dimension
# 0   P00813          1.219976                     62           1.513691
# 1   P00439          1.424472                     77           1.656789
# 2   P34897          1.261891                     62           1.734157
# 3   P21912          1.477573                     39           1.533105
# 4   P47989          1.419869                    206           1.909126

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Enzyme_ID              90 non-null     object
#  1   Shannon_Entropy        90 non-null     float64
#  2   Number_of_Transitions  90 non-null     int64
#  3   Fractal_Dimension      89 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
Df.describe()
# Out:
#        Shannon_Entropy  Number_of_Transitions  Fractal_Dimension
# count        90.000000              90.000000          89.000000
# mean          1.374843              75.677778           1.653146
# std           0.130175              54.618355           0.182979
# min           0.913012              11.000000           1.116563
# 25%           1.287220              41.250000           1.537908
# 50%           1.394973              63.000000           1.677307
# 75%           1.457596              92.000000           1.790078
# max           1.584585             386.000000           2.047670

# %% [markdown]
# **Enzymes Value distribution**

# %%
from matplotlib import pyplot as plt
_df_6['Number_of_Transitions'].plot(kind='line', figsize=(8, 4), title='Number_of_Transitions')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_7['Fractal_Dimension'].plot(kind='line', figsize=(8, 4), title='Fractal_Dimension')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_5['Shannon_Entropy'].plot(kind='line', figsize=(8, 4), title='Shannon_Entropy')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   TF_ID                  90 non-null     object
#  1   Shannon Entropy        90 non-null     float64
#  2   Number of Transitions  90 non-null     int64
#  3   Fractal Dimension      89 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
df.describe()
# Out:
#        Shannon Entropy  Number of Transitions  Fractal Dimension
# count        90.000000              90.000000          89.000000
# mean          1.413938              75.033333           1.594587
# std           0.088839              31.666610           0.101609
# min           1.182538              11.000000           1.341084
# 25%           1.361918              52.000000           1.522142
# 50%           1.436696              70.500000           1.594629
# 75%           1.474993              87.000000           1.655080
# max           1.578222             166.000000           1.870929

# %% [markdown]
# **Values visualization**

# %%
from matplotlib import pyplot as plt
_df_6['Number of Transitions'].plot(kind='line', figsize=(8, 4), title='Number of Transitions')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_7['Fractal Dimension'].plot(kind='line', figsize=(8, 4), title='Fractal Dimension')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_5['Shannon Entropy'].plot(kind='line', figsize=(8, 4), title='Shannon Entropy')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# **Distribution Analysis**

# %%
from matplotlib import pyplot as plt
_df_1['Number of Transitions'].plot(kind='hist', bins=20, title='Number of Transitions')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_2['Fractal Dimension'].plot(kind='hist', bins=20, title='Fractal Dimension')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Shannon Entropy'].plot(kind='hist', bins=20, title='Shannon Entropy')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ##**Exploratory Data Analysis**

# %% [markdown]
# ##**Correlation**

# %% [markdown]
# **TF correlation**

# %%
#Finding correlations between the variables using iloc function

corr_df = df.iloc[:,1:4].corr()
corr_df
# Out:
#                        Shannon Entropy  Number of Transitions  \
# Shannon Entropy               1.000000               0.300735
# Number of Transitions         0.300735               1.000000
# Fractal Dimension             0.070290               0.720099
#
#                        Fractal Dimension
# Shannon Entropy                 0.070290
# Number of Transitions           0.720099
# Fractal Dimension               1.000000

# %% [markdown]
# **Enzymes Correlation**

# %%
corr_Df = Df.iloc[:,1:4].corr()
corr_Df
# Out:
#                        Shannon_Entropy  Number_of_Transitions  \
# Shannon_Entropy               1.000000               0.038089
# Number_of_Transitions         0.038089               1.000000
# Fractal_Dimension            -0.022137               0.728904
#
#                        Fractal_Dimension
# Shannon_Entropy                -0.022137
# Number_of_Transitions           0.728904
# Fractal_Dimension               1.000000

# %% [markdown]
# ##**Heat map**

# %% [markdown]
# **Transcription factor Heat Map**

# %%
#Creating a heatmap to pinpoint the columns in the DataFrame exhibiting high correlation.

plt.figure(figsize=(14, 8))
sns.heatmap(data=corr_df, annot=True, cmap='YlGnBu')  # 'annot=True' fills the R values in the heatmap cells.

plt.show()

# %% [markdown]
# **Enzymes Heat Map**

# %%
plt.figure(figsize=(14, 8))
sns.heatmap(data=corr_Df, annot=True, cmap='YlGnBu')  # 'annot=True' fills the R values in the heatmap cells.

plt.show()

# %% [markdown]
# ##**Boxplot analysis**

# %% [markdown]
# **Box Plot for TFs**

# %%
num=df.select_dtypes(include=[np.number])
fig = plt.figure(figsize = (60, 90))
j = 0
for i in num.columns:
    plt.subplot(11, 5, j+1)
    j += 1
    sns.boxplot(y=num[i], width=0.3, palette="Set1")
fig.suptitle('Scatterplot Analysis')
fig.tight_layout()
fig.subplots_adjust(top=0.95)
plt.show()
# Out:
# <ipython-input-26-1ece428011a1>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=num[i], width=0.3, palette="Set1")
# <ipython-input-26-1ece428011a1>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=num[i], width=0.3, palette="Set1")
# <ipython-input-26-1ece428011a1>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=num[i], width=0.3, palette="Set1")

# %% [markdown]
# **Box Plot for Enzymes**

# %%
num=Df.select_dtypes(include=[np.number])
fig = plt.figure(figsize = (40, 90))
j = 0
for i in num.columns:
    plt.subplot(11, 5, j+1)
    j += 1
    sns.boxplot(y=num[i], width=0.9, palette="Set2")
fig.suptitle('Scatterplot Analysis')
fig.tight_layout()
fig.subplots_adjust(top=0.95)
plt.show()
# Out:
# <ipython-input-21-e73d8012b47a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=num[i], width=0.9, palette="Set2")
# <ipython-input-21-e73d8012b47a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=num[i], width=0.9, palette="Set2")
# <ipython-input-21-e73d8012b47a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=num[i], width=0.9, palette="Set2")

# %% [markdown]
# **Scatter plot - Just to have an Idea**

# %%
# Assuming data is in a DataFrame called df
plt.scatter(df['Shannon_Entropy'], df['Fractal_Dimension'])
plt.xlabel('Shannon_Entropy')
plt.ylabel('Fractal_Dimension')
plt.title('Scatter Plot of Shannon Entropy vs. Number of Transitions')
plt.show()

# %% [markdown]
# **Comparing TF's Shannon Entropy values and Fractal Dimensions values**

# %%
plt.scatter(df.index, df['Shannon_Entropy'], color='green', label='Shannon Entropy')
plt.scatter(df.index, df['Fractal_Dimension'], color='red', label='Fractal Dimension')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Scatter Plot of Shannon Entropy and Fractal Dimension')
plt.legend()
plt.show()

# %% [markdown]
# From this we can say Most of the time fractor Dimension values are higher that the Shannon Entropy values in TFs.

# %% [markdown]
# **Comparing Enzyme's Shannon Entropy values and Fractal Dimensions values**

# %%
plt.scatter(Df.index, Df['Shannon_Entropy'], color='green', label='Shannon Entropy')
plt.scatter(Df.index, Df['Fractal_Dimension'], color='red', label='Fractal Dimension')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Scatter Plot of Shannon Entropy and Fractal Dimension')
plt.legend()
plt.show()

# %% [markdown]
# From this we can say Most of the time fractor Dimension values are higher that the Shannon Entropy values in Enzymes too.

# %% [markdown]
# **Line Plot of dataset**

# %% [markdown]
# **For TFs**

# %%
plt.plot(df.index, df['Shannon_Entropy'], color='green', label='Shannon Entropy')
plt.plot(df.index, df['Fractal_Dimension'], color='red', label='Fractal Dimension')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Line Plot of Shannon Entropy and Fractal Dimension')
plt.legend()
plt.show()

# %% [markdown]
# **For Enzymes**

# %%
plt.plot(Df.index, Df['Shannon_Entropy'], color='green', label='Shannon Entropy')
plt.plot(Df.index, Df['Fractal_Dimension'], color='red', label='Fractal Dimension')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Line Plot of Shannon Entropy and Fractal Dimension')
plt.legend()
plt.show()

# %% [markdown]
# **Violin Plot of Shannon Entropy and Number of Transitions**

# %% [markdown]
# **For TFs : **

# %%
df_melted = df.melt(value_vars=['Shannon_Entropy', 'Fractal_Dimension'], var_name='Metric', value_name='Value')

plt.figure(figsize=(10, 6))
sns.violinplot(x='Metric', y='Value', data=df_melted, palette="Set2")
plt.title('Violin Plot of Shannon Entropy & Fractal Dimension')
plt.show()
# Out:
# <ipython-input-30-ea5efd1dbf50>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Metric', y='Value', data=df_melted, palette="Set2")

# %% [markdown]
# **For Enzymes:**

# %%
Df_melted = Df.melt(value_vars=['Shannon_Entropy', 'Fractal_Dimension'], var_name='Metric', value_name='Value')

plt.figure(figsize=(10, 6))
sns.violinplot(x='Metric', y='Value', data=df_melted, palette="Set1")
plt.title('Violin Plot of Shannon Entropy & Fractal Dimension')
plt.show()
# Out:
# <ipython-input-31-c5b923ae7b92>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Metric', y='Value', data=df_melted, palette="Set1")

# %%
df_melted = df.melt(value_vars=['Shannon_Entropy', 'Fractal_Dimension'], var_name='Metric', value_name='Value')
Df_melted = Df.melt(value_vars=['Shannon_Entropy', 'Fractal_Dimension'], var_name='Metric', value_name='Value')

fig, axes = plt.subplots(1, 2, figsize=(20, 6))

sns.violinplot(x='Metric', y='Value', data=df_melted, palette="Set2", ax=axes[0])
axes[0].set_title('Violin Plot of Shannon Entropy & Fractal Dimension (Dataset 1)')

sns.violinplot(x='Metric', y='Value', data=Df_melted, palette="Set1", ax=axes[1])
axes[1].set_title('Violin Plot of Shannon Entropy & Fractal Dimension (Dataset 2)')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-33-bb463371bf0e>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Metric', y='Value', data=df_melted, palette="Set2", ax=axes[0])
# <ipython-input-33-bb463371bf0e>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Metric', y='Value', data=Df_melted, palette="Set1", ax=axes[1])

# %%
df_melted = df.melt(value_vars=['Shannon_Entropy'], var_name='Metric', value_name='Value')
Df_melted = Df.melt(value_vars=['Shannon_Entropy'], var_name='Metric', value_name='Value')

df_melted['Dataset'] = 'Tfs'
Df_melted['Dataset'] = 'Enzymes'

combined_df_entropy = pd.concat([df_melted, Df_melted])

df_melted_fd = df.melt(value_vars=['Fractal_Dimension'], var_name='Metric', value_name='Value')
Df_melted_fd = Df.melt(value_vars=['Fractal_Dimension'], var_name='Metric', value_name='Value')

df_melted_fd['Dataset'] = 'Dataset 1'
Df_melted_fd['Dataset'] = 'Dataset 2'
combined_df_fd = pd.concat([df_melted_fd, Df_melted_fd])

fig, axes = plt.subplots(1, 2, figsize=(20, 6))

sns.violinplot(x='Metric', y='Value', hue='Dataset', data=combined_df_entropy, palette="Set2", ax=axes[0])
axes[0].set_title('Violin Plot of Shannon Entropy')

sns.violinplot(x='Metric', y='Value', hue='Dataset', data=combined_df_fd, palette="Set1", ax=axes[1])
axes[1].set_title('Violin Plot of Fractal Dimension')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-ace1c88cd202> in <cell line: 21>()
#      19 axes[0].set_title('Violin Plot of Shannon Entropy')
#      20
# ---> 21 sns.violinplot(x='Metric', y='Value', hue='Dataset', data=combined_df_fd, palette="Set1", ax=axes[1])
#      22 axes[1].set_title('Violin Plot of Fractal Dimension')
#      23
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1768     inner_kws = {} if inner_kws is None else inner_kws.copy()
#    1769
# -> 1770     p.plot_violins(
#    1771         width=width,
# ...

# %%
df_melted_entropy = df.melt(value_vars=['Shannon_Entropy'], var_name='Metric', value_name='Value')
Df_melted_entropy = Df.melt(value_vars=['Shannon_Entropy'], var_name='Metric', value_name='Value')

df_melted_entropy['Dataset'] = 'Tfs'
Df_melted_entropy['Dataset'] = 'Enzymes'

combined_df_entropy = pd.concat([df_melted_entropy, Df_melted_entropy]).reset_index(drop=True)

plt.figure(figsize=(10, 6))
sns.violinplot(x='Metric', y='Value', hue='Dataset', data=combined_df_entropy, palette="Set2")
plt.title('Violin Plot of Shannon Entropy')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, palette="Set2")
plt.title('Outlier Box Plot of Shannon Entropy and Number of Transitions')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Convert values in rows to lists**

# %% [markdown]
# **TF values:**

# %%
# convert Shannon Entropy values to a list
SE_list = df.Shannon_Entropy.tolist()
print(SE_list)

# convert Number of Transitions values to a list
NT_list = df.Number_of_Transitions.tolist()
print(NT_list)

# convert Fractal Dimension values to a list
FD_list = df.Fractal_Dimension.tolist()
print(FD_list)
# Out:
# [1.400063043, 1.340513908, 1.480286188, 1.358966209, 1.494393995, 1.377868223, 1.523245485, 1.438154671, 1.422531117, 1.5284302, 1.388616551, 1.411224798, 1.238896229, 1.361149331, 1.505404844, 1.538255233, 1.337401555, 1.279630097, 1.567668805, 1.480364839, 1.491134239, 1.33818303, 1.378108928, 1.410990183, 1.361499651, 1.30137837, 1.491764084, 1.444948676, 1.482695341, 1.462694779, 1.376120212, 1.425026089, 1.458526955, 1.247386097, 1.405388484, 1.228292493, 1.437830115, 1.475458136, 1.341367956, 1.449034991, 1.478388175, 1.464635007, 1.377076801, 1.363173294, 1.435561455, 1.332080383, 1.448011205, 1.396798164, 1.553226356, 1.419661773, 1.231622247, 1.46321479, 1.373143975, 1.393527026, 1.47290414, 1.481723648, 1.384011112, 1.319998988, 1.254116468, 1.297688732, 1.469887755, 1.45749536, 1.454640486, 1.549093619, 1.440026173, 1.459651803, 1.25532269, 1.452700508, 1.513051116, 1.397541645, 1.182538184, 1.395967075, 1.22668002, 1.504566971, 1.407132335, 1.439010056, 1.554739008, 1.467
# ...

# %% [markdown]
# **Enzymes values:**

# %%
# convert Shannon Entropy values to a list
SE1_list = Df.Shannon_Entropy.tolist()
print(SE_list)

# convert Number of Transitions values to a list
NT1_list = Df.Number_of_Transitions.tolist()
print(NT_list)

# convert Fractal Dimension values to a list
FD1_list = Df.Fractal_Dimension.tolist()
print(FD_list)
# Out:
# [1.400063043, 1.340513908, 1.480286188, 1.358966209, 1.494393995, 1.377868223, 1.523245485, 1.438154671, 1.422531117, 1.5284302, 1.388616551, 1.411224798, 1.238896229, 1.361149331, 1.505404844, 1.538255233, 1.337401555, 1.279630097, 1.567668805, 1.480364839, 1.491134239, 1.33818303, 1.378108928, 1.410990183, 1.361499651, 1.30137837, 1.491764084, 1.444948676, 1.482695341, 1.462694779, 1.376120212, 1.425026089, 1.458526955, 1.247386097, 1.405388484, 1.228292493, 1.437830115, 1.475458136, 1.341367956, 1.449034991, 1.478388175, 1.464635007, 1.377076801, 1.363173294, 1.435561455, 1.332080383, 1.448011205, 1.396798164, 1.553226356, 1.419661773, 1.231622247, 1.46321479, 1.373143975, 1.393527026, 1.47290414, 1.481723648, 1.384011112, 1.319998988, 1.254116468, 1.297688732, 1.469887755, 1.45749536, 1.454640486, 1.549093619, 1.440026173, 1.459651803, 1.25532269, 1.452700508, 1.513051116, 1.397541645, 1.182538184, 1.395967075, 1.22668002, 1.504566971, 1.407132335, 1.439010056, 1.554739008, 1.467
# ...

# %%
data = {
    'Shannon Entropy': (1.400063043, 1.340513908, 1.480286188, 1.358966209, 1.494393995, 1.377868223, 1.523245485, 1.438154671, 1.422531117, 1.5284302, 1.388616551, 1.411224798, 1.238896229, 1.361149331, 1.505404844, 1.538255233, 1.337401555, 1.279630097, 1.567668805, 1.480364839, 1.491134239, 1.33818303, 1.378108928, 1.410990183, 1.361499651, 1.30137837, 1.491764084, 1.444948676, 1.482695341, 1.462694779, 1.376120212, 1.425026089, 1.458526955, 1.247386097, 1.405388484, 1.228292493, 1.437830115, 1.475458136, 1.341367956, 1.449034991, 1.478388175, 1.464635007, 1.377076801, 1.363173294, 1.435561455, 1.332080383, 1.448011205, 1.396798164, 1.553226356, 1.419661773, 1.231622247, 1.46321479, 1.373143975, 1.340702107, 1.393527026, 1.47290414, 1.481723648, 1.384011112, 1.319998988, 1.254116468, 1.297688732, 1.469887755, 1.45749536, 1.454640486, 1.549093619, 1.440026173, 1.459651803, 1.25532269, 1.452700508, 1.513051116, 1.397541645, 1.182538184, 1.395967075, 1.22668002, 1.504566971, 1.407132335, 1.439010056, 1.554739008, 1.467783435, 1.385807882, 1.458943338, 1.443058605, 1.50523331, 1.48693042, 1.460582997, 1.514592067, 1.335435445, 1.222014372, 1.473597765, 1.578222416),# enter the actual data
    'Number of Transitions': (76, 70, 68, 64, 75, 73, 81, 77, 129, 88, 48, 125, 43, 82, 69, 83, 65, 96, 55, 55, 144, 135, 55, 79, 70, 80, 107, 71, 71, 49, 54, 96, 55, 32, 81, 34, 76, 76, 52, 44, 78, 74, 23, 41, 84, 150, 47, 46, 45, 71, 97, 102, 61, 82, 39, 67, 124, 122, 68, 61, 37, 51, 94, 166, 65, 45, 98, 44, 42, 129, 73, 31, 43, 97, 140, 42, 65, 80, 150, 83, 69, 59, 131, 68, 52, 96, 42, 11, 65, 120)# enter the actual data
}
df = pd.DataFrame(data)

# Define quantiles to be displayed
quantiles = [0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98]



# Create a function to calculate quantiles
def quantile_boxplot(data, quantiles):
    quantile_values = data.quantile(quantiles)
    return quantile_values

# Calculate quantiles for each column
quantile_data = df.apply(quantile_boxplot, quantiles=quantiles)

# Plotting the quantile box plot
plt.figure(figsize=(10, 6))
for column in quantile_data.columns:
    plt.plot(quantiles, quantile_data[column], marker='o', label=column)

plt.xlabel('Quantiles')
plt.ylabel('Values')
plt.title('Quantile Box Plot of Shannon Entropy and Number of Transitions')
plt.legend()
plt.show()

# %% [markdown]
# **Improve the visibility of Shannon entropy fluctuations**

# %%
data = {
    'Shannon Entropy': (1.400063043, 1.340513908, 1.480286188, 1.358966209, 1.494393995, 1.377868223, 1.523245485, 1.438154671, 1.422531117, 1.5284302, 1.388616551, 1.411224798, 1.238896229, 1.361149331, 1.505404844, 1.538255233, 1.337401555, 1.279630097, 1.567668805, 1.480364839, 1.491134239, 1.33818303, 1.378108928, 1.410990183, 1.361499651, 1.30137837, 1.491764084, 1.444948676, 1.482695341, 1.462694779, 1.376120212, 1.425026089, 1.458526955, 1.247386097, 1.405388484, 1.228292493, 1.437830115, 1.475458136, 1.341367956, 1.449034991, 1.478388175, 1.464635007, 1.377076801, 1.363173294, 1.435561455, 1.332080383, 1.448011205, 1.396798164, 1.553226356, 1.419661773, 1.231622247, 1.46321479, 1.373143975, 1.340702107, 1.393527026, 1.47290414, 1.481723648, 1.384011112, 1.319998988, 1.254116468, 1.297688732, 1.469887755, 1.45749536, 1.454640486, 1.549093619, 1.440026173, 1.459651803, 1.25532269, 1.452700508, 1.513051116, 1.397541645, 1.182538184, 1.395967075, 1.22668002, 1.504566971, 1.407132335, 1.439010056, 1.554739008, 1.467783435, 1.385807882, 1.458943338, 1.443058605, 1.50523331, 1.48693042, 1.460582997, 1.514592067, 1.335435445, 1.222014372, 1.473597765, 1.578222416),# enter the actual data
    'Number of Transitions': (76, 70, 68, 64, 75, 73, 81, 77, 129, 88, 48, 125, 43, 82, 69, 83, 65, 96, 55, 55, 144, 135, 55, 79, 70, 80, 107, 71, 71, 49, 54, 96, 55, 32, 81, 34, 76, 76, 52, 44, 78, 74, 23, 41, 84, 150, 47, 46, 45, 71, 97, 102, 61, 82, 39, 67, 124, 122, 68, 61, 37, 51, 94, 166, 65, 45, 98, 44, 42, 129, 73, 31, 43, 97, 140, 42, 65, 80, 150, 83, 69, 59, 131, 68, 52, 96, 42, 11, 65, 120)# enter the actual data
}
df = pd.DataFrame(data)

# Define quantiles to be displayed
quantiles = [0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98]

df = pd.DataFrame(data)

# Define quantiles to be displayed
quantiles = [0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98]

# Create a function to calculate quantiles
def quantile_boxplot(data, quantiles):
    quantile_values = data.quantile(quantiles)
    return quantile_values

# Calculate quantiles for each column
quantile_data = df.apply(quantile_boxplot, quantiles=quantiles)

# Plotting the quantile box plot
plt.figure(figsize=(12, 8))
for column in quantile_data.columns:
    plt.plot(quantiles, quantile_data[column], marker='o', label=column)

plt.xlabel('Quantiles', fontsize=14)
plt.ylabel('Values', fontsize=14)
plt.title('Quantile Box Plot of Shannon Entropy and Number of Transitions', fontsize=16)
plt.legend()
plt.grid(True)
plt.show()

# %%
data = {
    'Shannon_Entropy': [1.400063043, 1.340513908, 1.480286188, 1.358966209, 1.494393995, 1.377868223, 1.523245485, 1.438154671, 1.422531117, 1.5284302, 1.388616551, 1.411224798, 1.238896229, 1.361149331, 1.505404844, 1.538255233, 1.337401555, 1.279630097, 1.567668805, 1.480364839, 1.491134239, 1.33818303, 1.378108928, 1.410990183, 1.361499651, 1.30137837, 1.491764084, 1.444948676, 1.482695341, 1.462694779, 1.376120212, 1.425026089, 1.458526955, 1.247386097, 1.405388484, 1.228292493, 1.437830115, 1.475458136, 1.341367956, 1.449034991, 1.478388175, 1.464635007, 1.377076801, 1.363173294, 1.435561455, 1.332080383, 1.448011205, 1.396798164, 1.553226356, 1.419661773, 1.231622247, 1.46321479, 1.373143975, 1.393527026, 1.47290414, 1.481723648, 1.384011112, 1.319998988, 1.254116468, 1.297688732, 1.469887755, 1.45749536, 1.454640486, 1.549093619, 1.440026173, 1.459651803, 1.25532269, 1.452700508, 1.513051116, 1.397541645, 1.182538184, 1.395967075, 1.22668002, 1.504566971, 1.407132335, 1.439010056, 1.554739008, 1.467783435, 1.385807882, 1.458943338, 1.443058605, 1.50523331, 1.48693042, 1.460582997, 1.514592067, 1.335435445, 1.222014372, 1.473597765, 1.578222416],
    'Number_of_Transitions': [76, 70, 68, 64, 75, 73, 81, 77, 129, 88, 48, 125, 43, 82, 69, 83, 65, 96, 55, 55, 144, 135, 55, 79, 70, 80, 107, 71, 71, 49, 54, 96, 55, 32, 81, 34, 76, 76, 52, 44, 78, 74, 23, 41, 84, 150, 47, 46, 45, 71, 97, 102, 61, 39, 67, 124, 122, 68, 61, 37, 51, 94, 166, 65, 45, 98, 44, 42, 129, 73, 31, 43, 97, 140, 42, 65, 80, 150, 83, 69, 59, 131, 68, 52, 96, 42, 11, 65, 120],
    'Fractal_Dimension': [1.625713736, 1.658551912, 1.531153449, 1.640730039, 1.7137816, 1.641573078, 1.595382119, 1.553466443, 1.69291267, 1.672466562, 1.52214224, 1.731182711, 1.443657047, 1.662759345, 1.472019116, 1.51055623, 1.664412554, 1.820476666, 1.551913014, 1.698530975, 1.687512032, 1.764360358, 1.637772505, 1.609988565, 1.638329737, 1.554528817, 1.617032179, 1.596624074, 1.532148301, 1.541550167, 1.608167634, 1.565665447, 1.569314294, 1.505524841, 1.575481863, 1.512132074, 1.582699666, 1.491139162, 1.577587068, 1.575623839, 1.593682944, 1.568129438, 1.341083835, 1.485242235, 1.556234634, 1.711613926, 1.534458246, 1.47611256, 1.473438853, 1.780309968, 1.857244905, 1.638166143, 1.687339519, 1.408417853, 1.55688341, 1.626656892, 1.718477928, 1.565872989, 1.598785851, 1.497539138, 1.642203955, 1.61576998, 1.870929282, 1.648814717, 1.491633198, 1.578396114, 1.457041719, 1.446568155, 1.695918026, 1.594629249, 1.456328855, 1.595964418, 1.777834433, 1.661082022, 1.519740425, 1.487791221, 1.626115546, 1.712454193, 1.6129878, 1.655079757, 1.574892514, 1.69727046, 1.537250631, 1.48674293, 1.641318907, 1.496568475, 1.359496212, 1.50208163, 1.653095702]
}
df = pd.DataFrame(data)

# Define quantiles to be displayed
quantiles = [0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98]

# Create a function to calculate quantiles
def quantile_boxplot(data, quantiles):
    quantile_values = data.quantile(quantiles)
    return quantile_values

# Calculate quantiles for each column
quantile_data = df.apply(quantile_boxplot, quantiles=quantiles)

# Plotting the quantile box plot
plt.figure(figsize=(12, 8))
for column in quantile_data.columns:
    plt.plot(quantiles, quantile_data[column], marker='o', label=column)

plt.xlabel('Quantiles', fontsize=14)
plt.ylabel('Values', fontsize=14)
plt.title('Quantile Box Plot of Shannon Entropy, Number of Transitions, and Fractal Dimension', fontsize=16)
plt.legend()
plt.grid(True)
plt.show()

# %%
data = {
    'Shannon_Entropy': [1.400063043, 1.340513908, 1.480286188, 1.358966209, 1.494393995, 1.377868223, 1.523245485, 1.438154671, 1.422531117, 1.5284302, 1.388616551, 1.411224798, 1.238896229, 1.361149331, 1.505404844, 1.538255233, 1.337401555, 1.279630097, 1.567668805, 1.480364839, 1.491134239, 1.33818303, 1.378108928, 1.410990183, 1.361499651, 1.30137837, 1.491764084, 1.444948676, 1.482695341, 1.462694779, 1.376120212, 1.425026089, 1.458526955, 1.247386097, 1.405388484, 1.228292493, 1.437830115, 1.475458136, 1.341367956, 1.449034991, 1.478388175, 1.464635007, 1.377076801, 1.363173294, 1.435561455, 1.332080383, 1.448011205, 1.396798164, 1.553226356, 1.419661773, 1.231622247, 1.46321479, 1.373143975, 1.393527026, 1.47290414, 1.481723648, 1.384011112, 1.319998988, 1.254116468, 1.297688732, 1.469887755, 1.45749536, 1.454640486, 1.549093619, 1.440026173, 1.459651803, 1.25532269, 1.452700508, 1.513051116, 1.397541645, 1.182538184, 1.395967075, 1.22668002, 1.504566971, 1.407132335, 1.439010056, 1.554739008, 1.467783435, 1.385807882, 1.458943338, 1.443058605, 1.50523331, 1.48693042, 1.460582997, 1.514592067, 1.335435445, 1.222014372, 1.473597765, 1.578222416],

    'Fractal_Dimension': [1.625713736, 1.658551912, 1.531153449, 1.640730039, 1.7137816, 1.641573078, 1.595382119, 1.553466443, 1.69291267, 1.672466562, 1.52214224, 1.731182711, 1.443657047, 1.662759345, 1.472019116, 1.51055623, 1.664412554, 1.820476666, 1.551913014, 1.698530975, 1.687512032, 1.764360358, 1.637772505, 1.609988565, 1.638329737, 1.554528817, 1.617032179, 1.596624074, 1.532148301, 1.541550167, 1.608167634, 1.565665447, 1.569314294, 1.505524841, 1.575481863, 1.512132074, 1.582699666, 1.491139162, 1.577587068, 1.575623839, 1.593682944, 1.568129438, 1.341083835, 1.485242235, 1.556234634, 1.711613926, 1.534458246, 1.47611256, 1.473438853, 1.780309968, 1.857244905, 1.638166143, 1.687339519, 1.408417853, 1.55688341, 1.626656892, 1.718477928, 1.565872989, 1.598785851, 1.497539138, 1.642203955, 1.61576998, 1.870929282, 1.648814717, 1.491633198, 1.578396114, 1.457041719, 1.446568155, 1.695918026, 1.594629249, 1.456328855, 1.595964418, 1.777834433, 1.661082022, 1.519740425, 1.487791221, 1.626115546, 1.712454193, 1.6129878, 1.655079757, 1.574892514, 1.69727046, 1.537250631, 1.48674293, 1.641318907, 1.496568475, 1.359496212, 1.50208163, 1.653095702]
}
df = pd.DataFrame(data)

# Define quantiles to be displayed
quantiles = [0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98]

# Create a function to calculate quantiles
def quantile_boxplot(data, quantiles):
    quantile_values = data.quantile(quantiles)
    return quantile_values

# Calculate quantiles for each column
quantile_data = df.apply(quantile_boxplot, quantiles=quantiles)

# Plotting the quantile box plot
plt.figure(figsize=(12, 8))
for column in quantile_data.columns:
    plt.plot(quantiles, quantile_data[column], marker='o', label=column)

plt.xlabel('Quantiles', fontsize=14)
plt.ylabel('Values', fontsize=14)
plt.title('Quantile Box Plot of Shannon Entropy, Number of Transitions and Fractal Dimension', fontsize=16)
plt.legend()
plt.grid(True)
plt.show()

# %%
data_df = {
    'Shannon_Entropy': [1.400063043, 1.340513908, 1.480286188, 1.358966209, 1.494393995, 1.377868223, 1.523245485, 1.438154671, 1.422531117, 1.5284302, 1.388616551, 1.411224798, 1.238896229, 1.361149331, 1.505404844, 1.538255233, 1.337401555, 1.279630097, 1.567668805, 1.480364839, 1.491134239, 1.33818303, 1.378108928, 1.410990183, 1.361499651, 1.30137837, 1.491764084, 1.444948676, 1.482695341, 1.462694779, 1.376120212, 1.425026089, 1.458526955, 1.247386097, 1.405388484, 1.228292493, 1.437830115, 1.475458136, 1.341367956, 1.449034991, 1.478388175],

    'Fractal_Dimension': [1.625713736, 1.658551912, 1.531153449, 1.640730039, 1.7137816, 1.641573078, 1.595382119, 1.553466443, 1.69291267, 1.672466562, 1.52214224, 1.731182711, 1.443657047, 1.662759345, 1.472019116, 1.51055623, 1.664412554, 1.820476666, 1.551913014, 1.698530975, 1.687512032, 1.764360358, 1.637772505, 1.609988565, 1.638329737, 1.554528817, 1.617032179, 1.596624074, 1.532148301, 1.541550167, 1.608167634, 1.565665447, 1.569314294, 1.505524841, 1.575481863, 1.512132074, 1.582699666, 1.491139162, 1.577587068, 1.575623839, 1.593682944]
}
df = pd.DataFrame(data_df)

# Sample data for Df
data_Df = {
    'Shannon_Entropy': [1.400063043, 1.340513908, 1.480286188, 1.358966209, 1.494393995, 1.377868223, 1.523245485, 1.438154671, 1.422531117, 1.5284302, 1.388616551, 1.411224798, 1.238896229, 1.361149331, 1.505404844, 1.538255233, 1.337401555, 1.279630097, 1.567668805, 1.480364839, 1.491134239, 1.33818303, 1.378108928, 1.410990183, 1.361499651, 1.30137837, 1.491764084, 1.444948676, 1.482695341, 1.462694779, 1.376120212, 1.425026089, 1.458526955, 1.247386097, 1.405388484, 1.228292493, 1.437830115, 1.475458136, 1.341367956, 1.449034991, 1.478388175, 1.464635007, 1.377076801, 1.363173294, 1.435561455, 1.332080383, 1.448011205, 1.396798164, 1.553226356, 1.419661773, 1.231622247, 1.46321479, 1.373143975, 1.393527026, 1.47290414, 1.481723648, 1.384011112, 1.319998988, 1.254116468, 1.297688732, 1.469887755, 1.45749536, 1.454640486, 1.549093619, 1.440026173, 1.459651803, 1.25532269, 1.452700508, 1.513051116, 1.397541645, 1.182538184, 1.395967075, 1.22668002, 1.504566971, 1.407132335, 1.439010056, 1.554739008, 1.467783435, 1.385807882, 1.458943338, 1.443058605, 1.50523331, 1.48693042, 1.460582997, 1.514592067, 1.335435445, 1.222014372, 1.473597765, 1.578222416],
    'Fractal_Dimension': [1.625713736, 1.658551912, 1.531153449, 1.640730039, 1.7137816, 1.641573078, 1.595382119, 1.553466443, 1.69291267, 1.672466562, 1.52214224, 1.731182711, 1.443657047, 1.662759345, 1.472019116, 1.51055623, 1.664412554, 1.820476666, 1.551913014, 1.698530975, 1.687512032, 1.764360358, 1.637772505, 1.609988565, 1.638329737, 1.554528817, 1.617032179, 1.596624074, 1.532148301, 1.541550167, 1.608167634, 1.565665447, 1.569314294, 1.505524841, 1.575481863, 1.512132074, 1.582699666, 1.491139162, 1.577587068, 1.575623839, 1.593682944, 1.568129438, 1.341083835, 1.485242235, 1.556234634, 1.711613926, 1.534458246, 1.47611256, 1.473438853, 1.780309968, 1.857244905, 1.638166143, 1.687339519, 1.408417853, 1.55688341, 1.626656892, 1.718477928, 1.565872989, 1.598785851, 1.497539138, 1.642203955, 1.61576998, 1.870929282, 1.648814717, 1.491633198, 1.578396114, 1.457041719, 1.446568155, 1.695918026, 1.594629249, 1.456328855, 1.595964418, 1.777834433, 1.661082022, 1.519740425, 1.487791221, 1.626115546, 1.712454193, 1.6129878, 1.655079757, 1.574892514, 1.69727046, 1.537250631, 1.48674293, 1.641318907, 1.496568475, 1.359496212, 1.50208163, 1.653095702]
}
Df = pd.DataFrame(data_Df)

# Define quantiles to be displayed
quantiles = [0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98]

# Create a function to calculate quantiles
def quantile_boxplot(data, quantiles):
    quantile_values = data.quantile(quantiles)
    return quantile_values

# Calculate quantiles for each column in df
quantile_data_df = df.apply(quantile_boxplot, quantiles=quantiles)

# Calculate quantiles for each column in Df
quantile_data_Df = Df.apply(quantile_boxplot, quantiles=quantiles)

# Combine the quantile data
combined_quantile_data = pd.concat([quantile_data_df, quantile_data_Df], axis=1, keys=['TF', 'Enzyme'])

# Plotting the quantile box plot
plt.figure(figsize=(12, 8))
for dataset in combined_quantile_data.columns.levels[0]:
    for column in combined_quantile_data[dataset].columns:
        plt.plot(quantiles, combined_quantile_data[dataset][column], marker='o', label=f'{dataset} - {column}')

plt.xlabel('Quantiles', fontsize=14)
plt.ylabel('Values', fontsize=14)
plt.title('Quantile Box Plot of Shannon Entropy and Fractal Dimension', fontsize=16)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Implemeting Logorithmic scale to Compare in detail**

# %%
# Create a function to calculate quantiles
def quantile_boxplot(data, quantiles):
    quantile_values = data.quantile(quantiles)
    return quantile_values

# Calculate quantiles for each column
quantile_data = df.apply(quantile_boxplot, quantiles=quantiles)

# Plotting the quantile box plot with logarithmic scale
plt.figure(figsize=(12, 8))
for column in quantile_data.columns:
    plt.plot(quantiles, quantile_data[column], marker='o', label=column)

plt.xlabel('Quantiles', fontsize=14)
plt.ylabel('Values (Log Scale)', fontsize=14)
plt.yscale('log')
plt.title('Quantile Box Plot of Shannon Entropy and Fractal Dimension (Log Scale)', fontsize=16)
plt.legend()
plt.grid(True, which="both", ls="--")
plt.show()

# %%
# Create a function to calculate quantiles
def quantile_boxplot(data, quantiles):
    quantile_values = data.quantile(quantiles)
    return quantile_values

# Calculate quantiles for each column in df
quantile_data_df = df.apply(quantile_boxplot, quantiles=quantiles)

# Calculate quantiles for each column in Df
quantile_data_Df = Df.apply(quantile_boxplot, quantiles=quantiles)

# Plotting the quantile box plot with logarithmic scale
plt.figure(figsize=(12, 8))
# Plot quantiles for df
for column in quantile_data_df.columns:
    plt.plot(quantiles, quantile_data_df[column], marker='o', label=f'TF - {column}')

# Plot quantiles for Df
for column in quantile_data_Df.columns:
    plt.plot(quantiles, quantile_data_Df[column], marker='x', linestyle='--', label=f'Enzyme - {column}')

plt.xlabel('Quantiles', fontsize=14)
plt.ylabel('Values (Log Scale)', fontsize=14)
plt.yscale('log')
plt.title('Quantile Box Plot of Shannon Entropy and Fractal Dimension (Log Scale)', fontsize=16)
plt.legend()
plt.grid(True, which="both", ls="--")
plt.show()

# %%
# Melt the DataFrame to long-form for easier plotting with Seaborn
df_melted = df.melt(var_name='Variable', value_name='Value')

# Create the box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Variable', y='Value', data=df_melted, palette="Set2")

# Overlay the scatter plot
sns.stripplot(x='Variable', y='Value', data=df_melted, color='red', jitter=True, size=5)

# Adding title and labels
plt.title('Box Plot with Overlaid Scatter Plot')
plt.xlabel('Variable')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# **Plotting the data points with BoxPlot & Probability density function**

# %%
from scipy.stats import norm

# %%
# Create a figure with subplots
fig, ax = plt.subplots(2, 1, figsize=(10, 12), gridspec_kw={'height_ratios': [1, 3]})

# Box plot
sns.boxplot(data=df, ax=ax[0], palette="Set2")
ax[0].set_title('Box Plot')

# Probability Density Function (PDF)
for column in df.columns:
    sns.kdeplot(df[column], ax=ax[1], fill=True, label=column)
    mean = df[column].mean()
    std = df[column].std()
    x = np.linspace(mean - 3*std, mean + 3*std, 100)
    y = norm.pdf(x, mean, std)
    ax[1].plot(x, y, label=f'{column} PDF')

ax[1].set_title('Probability Density Function (PDF)')
ax[1].legend()
plt.tight_layout()
plt.show()
