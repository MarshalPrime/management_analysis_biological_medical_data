# %% [markdown]
# # Import Libraries

# %%
# Library imports 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from Bio.PDB import PDBList, PDBParser
import py3Dmol 
import requests 
import os
from scipy.stats import linregress

# %% [markdown]
# ## Fetch PDB From AlphaFold

# %%
def fetch_pdb_from_alphafold(uniprot_ids,folder_name):

    # Create the folder if it doesn't exist
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)

    pdb_dict = {}  # Dictionary to store UniProt ID and PDB content
    
    for uniprot_id in uniprot_ids:
        try:
            # AlphaFold API URL to get the prediction model
            url = f"https://alphafold.ebi.ac.uk/api/prediction/{uniprot_id}"

            # Send GET request to the AlphaFold API
            response = requests.get(url)

            # Check if the request was successful
            if response.status_code == 200:
                data = response.json()  # Parse JSON data
                # Extract the PDB URL from the response
                pdb_url = data[0]['pdbUrl']
                print(f"AlphaFold predicted model PDB URL for {uniprot_id}: {pdb_url}")

                # Download the PDB file content
                pdb_response = requests.get(pdb_url)
                pdb_data = pdb_response.text  # Get the PDB data as text

                #Store PDB data in dictionary
                pdb_dict[uniprot_id] = pdb_data

                # Save the PDB data to a file
                pdb_filename = os.path.join(folder_name, f'{uniprot_id}.pdb')
                with open(pdb_filename, 'w') as pdb_file:
                    pdb_file.write(pdb_data)
                print(f"PDB file saved as {pdb_filename}")

            else:
                print(f"Failed to retrieve data for UniProt ID {uniprot_id}. Status code: {response.status_code}")
        
        except Exception as e:
            print(f"An error occurred for UniProt ID {uniprot_id}: {e}")

# %% [markdown]
# ### Import Enzymes and Transcript Factors with their UniProt_ID

# %%
file_path = "/home/marshal/protonotebook/Management and analysis of Biological and Medical Data/Protein Complexity - Enzymes_Protogene.csv"

# Read 100 Enzymes
enzymes = pd.read_csv(file_path)

file_path_2 = "/home/marshal/protonotebook/Management and analysis of Biological and Medical Data/Protein Complexity - Transcription Factor_Protogene.csv"

# Read 100 Transcript Factors
transcript_factor = pd.read_csv(file_path_2)

# %% [markdown]
# ### Display view Of Enzymes

# %%
#View Enzymes
enzymes
# Out:
#                      Enzyme Name UniProt ID
# 0          Alcohol dehydrogenase     Q8W3K0
# 1                Glucose oxidase     P13006
# 2               Xanthine oxidase     P47989
# 3          Lactate dehydrogenase     P00342
# 4           Malate dehydrogenase     P40925
# ..                           ...        ...
# 95        Aldehyde dehydrogenase     P00352
# 96       Fructose-bisphosphatase     P09083
# 97  Hydroxyglutaryl-CoA synthase     P54867
# 98            Glutamate synthase     P32245
# 99           Methionine synthase     P34897
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Overview Transcriptor Factors

# %%
#View TF
transcript_factor
# Out:
#    Transcription Factor Name UniProt ID
# 0                        p53     P04637
# 1                      RUNX1     P15063
# 2                        SP1     P08047
# 3                     TWIST1     Q15672
# 4                       ESR1     P03372
# ..                       ...        ...
# 95                      IRF1     P10914
# 96                       REL     Q04864
# 97                       SRF     P11831
# 98                     NR4A1     P22736
# 99                     CEBPB     P17676
#
# [100 rows x 2 columns]

# %% [markdown]
# # Merge my finds with Outcomes(90 Proteins)

# %%
file_path_3 = "/home/marshal/protonotebook/Management and analysis of Biological and Medical Data/File_enzyme.csv"
file_path_4 = "/home/marshal/protonotebook/Management and analysis of Biological and Medical Data/File_TF.csv"


# Read 90 Enzymes
enzymes_90 = pd.read_csv(file_path_3)

#Read 90 Transcriptor Factor
tf_90 = pd.read_csv(file_path_4)

# %% [markdown]
# ### Fecth PDB For Enzymes

# %%
# Fetch and visualize structures for all the given UniProt IDs

enzymes_pdb = fetch_pdb_from_alphafold(enzymes['UniProt ID'],'enzymes_pdb')
# Out:
# AlphaFold predicted model PDB URL for Q8W3K0: https://alphafold.ebi.ac.uk/files/AF-Q8W3K0-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/Q8W3K0.pdb
# AlphaFold predicted model PDB URL for P13006: https://alphafold.ebi.ac.uk/files/AF-P13006-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P13006.pdb
# AlphaFold predicted model PDB URL for P47989: https://alphafold.ebi.ac.uk/files/AF-P47989-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P47989.pdb
# AlphaFold predicted model PDB URL for P00342: https://alphafold.ebi.ac.uk/files/AF-P00342-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00342.pdb
# AlphaFold predicted model PDB URL for P40925: https://alphafold.ebi.ac.uk/files/AF-P40925-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P40925.pdb
# AlphaFold predicted model PDB URL for P08200: https://alphafold.ebi.ac.uk/files/AF-P08200-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P08200.pdb
# AlphaFold predicted model PDB URL for P04035: https://alphafold.ebi.ac.uk/files/AF-P04035-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P04035.pdb
# AlphaFold predicted model PDB URL for P53004: https://alphafold.ebi.ac.uk/files/AF-P53004-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P53004.pdb
# AlphaFold predicted model PDB URL for P50336: https://alphafold.ebi.ac.uk/files/AF-P50336-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P50336.pdb
# AlphaFold predicted model PDB URL for P21397: https://alphafold.ebi.ac.uk/files/AF-P21397-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P21397.pdb
# AlphaFold predicted model PDB URL for P52789: https://alphafold.ebi.ac.uk/files/AF-P52789-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P52789.pdb
# AlphaFold predicted model PDB URL for P35557: https://alphafold.ebi.ac.uk/files/AF-P35557-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P35557.pdb
# AlphaFold predicted model PDB URL for P08237: https://alphafold.ebi.ac.uk/files/AF-P08237-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P08237.pdb
# AlphaFold predicted model PDB URL for P00505: https://alphafold.ebi.ac.uk/files/AF-P00505-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00505.pdb
# AlphaFold predicted model PDB URL for P10266: https://alphafold.ebi.ac.uk/files/AF-P10266-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P10266.pdb
# AlphaFold predicted model PDB URL for P00579: https://alphafold.ebi.ac.uk/files/AF-P00579-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00579.pdb
# AlphaFold predicted model PDB URL for P13807: https://alphafold.ebi.ac.uk/files/AF-P13807-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P13807.pdb
# AlphaFold predicted model PDB URL for P00519: https://alphafold.ebi.ac.uk/files/AF-P00519-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00519.pdb
# AlphaFold predicted model PDB URL for P53597: https://alphafold.ebi.ac.uk/files/AF-P53597-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P53597.pdb
# AlphaFold predicted model PDB URL for P09211: https://alphafold.ebi.ac.uk/files/AF-P09211-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P09211.pdb
# AlphaFold predicted model PDB URL for P00691: https://alphafold.ebi.ac.uk/files/AF-P00691-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00691.pdb
# AlphaFold predicted model PDB URL for P16233: https://alphafold.ebi.ac.uk/files/AF-P16233-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P16233.pdb
# AlphaFold predicted model PDB URL for P00734: https://alphafold.ebi.ac.uk/files/AF-P00734-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00734.pdb
# AlphaFold predicted model PDB URL for P00639: https://alphafold.ebi.ac.uk/files/AF-P00639-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00639.pdb
# AlphaFold predicted model PDB URL for P04083: https://alphafold.ebi.ac.uk/files/AF-P04083-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P04083.pdb
# AlphaFold predicted model PDB URL for P24666: https://alphafold.ebi.ac.uk/files/AF-P24666-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P24666.pdb
# AlphaFold predicted model PDB URL for P04062: https://alphafold.ebi.ac.uk/files/AF-P04062-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P04062.pdb
# AlphaFold predicted model PDB URL for P00760: https://alphafold.ebi.ac.uk/files/AF-P00760-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00760.pdb
# AlphaFold predicted model PDB URL for P07374: https://alphafold.ebi.ac.uk/files/AF-P07374-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P07374.pdb
# AlphaFold predicted model PDB URL for P06276: https://alphafold.ebi.ac.uk/files/AF-P06276-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P06276.pdb
# AlphaFold predicted model PDB URL for P04075: https://alphafold.ebi.ac.uk/files/AF-P04075-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P04075.pdb
# AlphaFold predicted model PDB URL for P00929: https://alphafold.ebi.ac.uk/files/AF-P00929-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00929.pdb
# AlphaFold predicted model PDB URL for P07954: https://alphafold.ebi.ac.uk/files/AF-P07954-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P07954.pdb
# AlphaFold predicted model PDB URL for P19404: https://alphafold.ebi.ac.uk/files/AF-P19404-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P19404.pdb
# AlphaFold predicted model PDB URL for P07738: https://alphafold.ebi.ac.uk/files/AF-P07738-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P07738.pdb
# AlphaFold predicted model PDB URL for P30566: https://alphafold.ebi.ac.uk/files/AF-P30566-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P30566.pdb
# AlphaFold predicted model PDB URL for P00918: https://alphafold.ebi.ac.uk/files/AF-P00918-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00918.pdb
# AlphaFold predicted model PDB URL for P00811: https://alphafold.ebi.ac.uk/files/AF-P00811-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00811.pdb
# AlphaFold predicted model PDB URL for P04424: https://alphafold.ebi.ac.uk/files/AF-P04424-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P04424.pdb
# AlphaFold predicted model PDB URL for P00439: https://alphafold.ebi.ac.uk/files/AF-P00439-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00439.pdb
# AlphaFold predicted model PDB URL for P06744: https://alphafold.ebi.ac.uk/files/AF-P06744-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P06744.pdb
# AlphaFold predicted model PDB URL for P60174: https://alphafold.ebi.ac.uk/files/AF-P60174-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P60174.pdb
# AlphaFold predicted model PDB URL for P49247: https://alphafold.ebi.ac.uk/files/AF-P49247-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P49247.pdb
# AlphaFold predicted model PDB URL for P23284: https://alphafold.ebi.ac.uk/files/AF-P23284-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P23284.pdb
# AlphaFold predicted model PDB URL for P06744: https://alphafold.ebi.ac.uk/files/AF-P06744-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P06744.pdb
# AlphaFold predicted model PDB URL for P00547: https://alphafold.ebi.ac.uk/files/AF-P00547-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00547.pdb
# AlphaFold predicted model PDB URL for P09172: https://alphafold.ebi.ac.uk/files/AF-P09172-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P09172.pdb
# AlphaFold predicted model PDB URL for P00518: https://alphafold.ebi.ac.uk/files/AF-P00518-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00518.pdb
# AlphaFold predicted model PDB URL for P11388: https://alphafold.ebi.ac.uk/files/AF-P11388-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P11388.pdb
# AlphaFold predicted model PDB URL for P51648: https://alphafold.ebi.ac.uk/files/AF-P51648-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P51648.pdb
# AlphaFold predicted model PDB URL for P49917: https://alphafold.ebi.ac.uk/files/AF-P49917-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P49917.pdb
# AlphaFold predicted model PDB URL for P49918: https://alphafold.ebi.ac.uk/files/AF-P49918-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P49918.pdb
# AlphaFold predicted model PDB URL for P15104: https://alphafold.ebi.ac.uk/files/AF-P15104-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P15104.pdb
# AlphaFold predicted model PDB URL for P11498: https://alphafold.ebi.ac.uk/files/AF-P11498-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P11498.pdb
# AlphaFold predicted model PDB URL for P53597: https://alphafold.ebi.ac.uk/files/AF-P53597-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P53597.pdb
# AlphaFold predicted model PDB URL for P62877: https://alphafold.ebi.ac.uk/files/AF-P62877-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P62877.pdb
# AlphaFold predicted model PDB URL for P31327: https://alphafold.ebi.ac.uk/files/AF-P31327-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P31327.pdb
# AlphaFold predicted model PDB URL for P54136: https://alphafold.ebi.ac.uk/files/AF-P54136-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P54136.pdb
# AlphaFold predicted model PDB URL for P49917: https://alphafold.ebi.ac.uk/files/AF-P49917-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P49917.pdb
# AlphaFold predicted model PDB URL for P15104: https://alphafold.ebi.ac.uk/files/AF-P15104-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P15104.pdb
# AlphaFold predicted model PDB URL for P04040: https://alphafold.ebi.ac.uk/files/AF-P04040-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P04040.pdb
# AlphaFold predicted model PDB URL for P00433: https://alphafold.ebi.ac.uk/files/AF-P00433-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00433.pdb
# AlphaFold predicted model PDB URL for P00441: https://alphafold.ebi.ac.uk/files/AF-P00441-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00441.pdb
# Failed to retrieve data for UniProt ID P07203. Status code: 404
# AlphaFold predicted model PDB URL for P10599: https://alphafold.ebi.ac.uk/files/AF-P10599-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P10599.pdb
# AlphaFold predicted model PDB URL for P08684: https://alphafold.ebi.ac.uk/files/AF-P08684-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P08684.pdb
# AlphaFold predicted model PDB URL for P00374: https://alphafold.ebi.ac.uk/files/AF-P00374-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00374.pdb
# AlphaFold predicted model PDB URL for P21912: https://alphafold.ebi.ac.uk/files/AF-P21912-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P21912.pdb
# AlphaFold predicted model PDB URL for P00846: https://alphafold.ebi.ac.uk/files/AF-P00846-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00846.pdb
# AlphaFold predicted model PDB URL for P00791: https://alphafold.ebi.ac.uk/files/AF-P00791-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00791.pdb
# AlphaFold predicted model PDB URL for P00760: https://alphafold.ebi.ac.uk/files/AF-P00760-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00760.pdb
# AlphaFold predicted model PDB URL for P00766: https://alphafold.ebi.ac.uk/files/AF-P00766-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00766.pdb
# AlphaFold predicted model PDB URL for P08217: https://alphafold.ebi.ac.uk/files/AF-P08217-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P08217.pdb
# AlphaFold predicted model PDB URL for P03956: https://alphafold.ebi.ac.uk/files/AF-P03956-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P03956.pdb
# AlphaFold predicted model PDB URL for P00700: https://alphafold.ebi.ac.uk/files/AF-P00700-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00700.pdb
# AlphaFold predicted model PDB URL for P22303: https://alphafold.ebi.ac.uk/files/AF-P22303-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P22303.pdb
# AlphaFold predicted model PDB URL for P49327: https://alphafold.ebi.ac.uk/files/AF-P49327-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P49327.pdb
# AlphaFold predicted model PDB URL for P53341: https://alphafold.ebi.ac.uk/files/AF-P53341-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P53341.pdb
# AlphaFold predicted model PDB URL for P51659: https://alphafold.ebi.ac.uk/files/AF-P51659-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P51659.pdb
# AlphaFold predicted model PDB URL for P00439: https://alphafold.ebi.ac.uk/files/AF-P00439-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00439.pdb
# AlphaFold predicted model PDB URL for P11926: https://alphafold.ebi.ac.uk/files/AF-P11926-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P11926.pdb
# AlphaFold predicted model PDB URL for P10515: https://alphafold.ebi.ac.uk/files/AF-P10515-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P10515.pdb
# AlphaFold predicted model PDB URL for P53597: https://alphafold.ebi.ac.uk/files/AF-P53597-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P53597.pdb
# AlphaFold predicted model PDB URL for P61823: https://alphafold.ebi.ac.uk/files/AF-P61823-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P61823.pdb
# AlphaFold predicted model PDB URL for P00940: https://alphafold.ebi.ac.uk/files/AF-P00940-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00940.pdb
# AlphaFold predicted model PDB URL for P14174: https://alphafold.ebi.ac.uk/files/AF-P14174-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P14174.pdb
# AlphaFold predicted model PDB URL for P00813: https://alphafold.ebi.ac.uk/files/AF-P00813-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00813.pdb
# AlphaFold predicted model PDB URL for P04818: https://alphafold.ebi.ac.uk/files/AF-P04818-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P04818.pdb
# AlphaFold predicted model PDB URL for P00734: https://alphafold.ebi.ac.uk/files/AF-P00734-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00734.pdb
# AlphaFold predicted model PDB URL for P00558: https://alphafold.ebi.ac.uk/files/AF-P00558-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00558.pdb
# AlphaFold predicted model PDB URL for P00815: https://alphafold.ebi.ac.uk/files/AF-P00815-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00815.pdb
# AlphaFold predicted model PDB URL for P52209: https://alphafold.ebi.ac.uk/files/AF-P52209-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P52209.pdb
# AlphaFold predicted model PDB URL for P00374: https://alphafold.ebi.ac.uk/files/AF-P00374-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00374.pdb
# AlphaFold predicted model PDB URL for P46951: https://alphafold.ebi.ac.uk/files/AF-P46951-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P46951.pdb
# AlphaFold predicted model PDB URL for P35575: https://alphafold.ebi.ac.uk/files/AF-P35575-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P35575.pdb
# AlphaFold predicted model PDB URL for P00352: https://alphafold.ebi.ac.uk/files/AF-P00352-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P00352.pdb
# AlphaFold predicted model PDB URL for P09083: https://alphafold.ebi.ac.uk/files/AF-P09083-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P09083.pdb
# AlphaFold predicted model PDB URL for P54867: https://alphafold.ebi.ac.uk/files/AF-P54867-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P54867.pdb
# AlphaFold predicted model PDB URL for P32245: https://alphafold.ebi.ac.uk/files/AF-P32245-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P32245.pdb
# AlphaFold predicted model PDB URL for P34897: https://alphafold.ebi.ac.uk/files/AF-P34897-F1-model_v4.pdb
# PDB file saved as enzymes_pdb/P34897.pdb

# %%
# Fetch and visualize structures for all the given UniProt IDs

new_enzymes_pdb = fetch_pdb_from_alphafold(enzymes_90['Enzyme_ID'],'new_enzymes_pdb')
# Out:
# AlphaFold predicted model PDB URL for  P00813 : https://alphafold.ebi.ac.uk/files/AF-P00813-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00813 .pdb
# AlphaFold predicted model PDB URL for  P00439 : https://alphafold.ebi.ac.uk/files/AF-P00439-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00439 .pdb
# AlphaFold predicted model PDB URL for  P34897 : https://alphafold.ebi.ac.uk/files/AF-P34897-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P34897 .pdb
# AlphaFold predicted model PDB URL for  P21912 : https://alphafold.ebi.ac.uk/files/AF-P21912-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P21912 .pdb
# AlphaFold predicted model PDB URL for  P47989 : https://alphafold.ebi.ac.uk/files/AF-P47989-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P47989 .pdb
# AlphaFold predicted model PDB URL for  P50336 : https://alphafold.ebi.ac.uk/files/AF-P50336-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P50336 .pdb
# AlphaFold predicted model PDB URL for  P53004 : https://alphafold.ebi.ac.uk/files/AF-P53004-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P53004 .pdb
# AlphaFold predicted model PDB URL for  P53597 : https://alphafold.ebi.ac.uk/files/AF-P53597-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P53597 .pdb
# AlphaFold predicted model PDB URL for  P19404 : https://alphafold.ebi.ac.uk/files/AF-P19404-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P19404 .pdb
# AlphaFold predicted model PDB URL for  P00918 : https://alphafold.ebi.ac.uk/files/AF-P00918-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00918 .pdb
# AlphaFold predicted model PDB URL for  P49918 : https://alphafold.ebi.ac.uk/files/AF-P49918-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P49918 .pdb
# AlphaFold predicted model PDB URL for  P10266 : https://alphafold.ebi.ac.uk/files/AF-P10266-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P10266 .pdb
# AlphaFold predicted model PDB URL for  P04083 : https://alphafold.ebi.ac.uk/files/AF-P04083-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P04083 .pdb
# AlphaFold predicted model PDB URL for  P00342 : https://alphafold.ebi.ac.uk/files/AF-P00342-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00342 .pdb
# AlphaFold predicted model PDB URL for  P04424 : https://alphafold.ebi.ac.uk/files/AF-P04424-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P04424 .pdb
# AlphaFold predicted model PDB URL for  P00518 : https://alphafold.ebi.ac.uk/files/AF-P00518-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00518 .pdb
# AlphaFold predicted model PDB URL for  P52789 : https://alphafold.ebi.ac.uk/files/AF-P52789-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P52789 .pdb
# AlphaFold predicted model PDB URL for  P10515 : https://alphafold.ebi.ac.uk/files/AF-P10515-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P10515 .pdb
# AlphaFold predicted model PDB URL for  P00811 : https://alphafold.ebi.ac.uk/files/AF-P00811-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00811 .pdb
# AlphaFold predicted model PDB URL for  P35557 : https://alphafold.ebi.ac.uk/files/AF-P35557-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P35557 .pdb
# AlphaFold predicted model PDB URL for  P04075 : https://alphafold.ebi.ac.uk/files/AF-P04075-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P04075 .pdb
# AlphaFold predicted model PDB URL for  P35575 : https://alphafold.ebi.ac.uk/files/AF-P35575-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P35575 .pdb
# AlphaFold predicted model PDB URL for  P00766 : https://alphafold.ebi.ac.uk/files/AF-P00766-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00766 .pdb
# AlphaFold predicted model PDB URL for  P24666 : https://alphafold.ebi.ac.uk/files/AF-P24666-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P24666 .pdb
# AlphaFold predicted model PDB URL for  P04818 : https://alphafold.ebi.ac.uk/files/AF-P04818-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P04818 .pdb
# AlphaFold predicted model PDB URL for  P00558 : https://alphafold.ebi.ac.uk/files/AF-P00558-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00558 .pdb
# AlphaFold predicted model PDB URL for  P31327 : https://alphafold.ebi.ac.uk/files/AF-P31327-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P31327 .pdb
# AlphaFold predicted model PDB URL for  P08217 : https://alphafold.ebi.ac.uk/files/AF-P08217-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P08217 .pdb
# AlphaFold predicted model PDB URL for  P07738 : https://alphafold.ebi.ac.uk/files/AF-P07738-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P07738 .pdb
# AlphaFold predicted model PDB URL for  P23284 : https://alphafold.ebi.ac.uk/files/AF-P23284-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P23284 .pdb
# AlphaFold predicted model PDB URL for  P54867 : https://alphafold.ebi.ac.uk/files/AF-P54867-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P54867 .pdb
# AlphaFold predicted model PDB URL for  P00815 : https://alphafold.ebi.ac.uk/files/AF-P00815-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00815 .pdb
# AlphaFold predicted model PDB URL for  P13006 : https://alphafold.ebi.ac.uk/files/AF-P13006-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P13006 .pdb
# AlphaFold predicted model PDB URL for  P53341 : https://alphafold.ebi.ac.uk/files/AF-P53341-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P53341 .pdb
# AlphaFold predicted model PDB URL for  P51659 : https://alphafold.ebi.ac.uk/files/AF-P51659-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P51659 .pdb
# AlphaFold predicted model PDB URL for  P04062 : https://alphafold.ebi.ac.uk/files/AF-P04062-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P04062 .pdb
# AlphaFold predicted model PDB URL for  P00547 : https://alphafold.ebi.ac.uk/files/AF-P00547-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00547 .pdb
# AlphaFold predicted model PDB URL for  P00433 : https://alphafold.ebi.ac.uk/files/AF-P00433-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00433 .pdb
# AlphaFold predicted model PDB URL for  P08684 : https://alphafold.ebi.ac.uk/files/AF-P08684-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P08684 .pdb
# AlphaFold predicted model PDB URL for  P04035 : https://alphafold.ebi.ac.uk/files/AF-P04035-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P04035 .pdb
# AlphaFold predicted model PDB URL for  P40925 : https://alphafold.ebi.ac.uk/files/AF-P40925-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P40925 .pdb
# AlphaFold predicted model PDB URL for  P00846 : https://alphafold.ebi.ac.uk/files/AF-P00846-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00846 .pdb
# AlphaFold predicted model PDB URL for  P07954 : https://alphafold.ebi.ac.uk/files/AF-P07954-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P07954 .pdb
# AlphaFold predicted model PDB URL for  P22303 : https://alphafold.ebi.ac.uk/files/AF-P22303-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P22303 .pdb
# AlphaFold predicted model PDB URL for  P30566 : https://alphafold.ebi.ac.uk/files/AF-P30566-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P30566 .pdb
# AlphaFold predicted model PDB URL for  P08237 : https://alphafold.ebi.ac.uk/files/AF-P08237-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P08237 .pdb
# AlphaFold predicted model PDB URL for  P00691 : https://alphafold.ebi.ac.uk/files/AF-P00691-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00691 .pdb
# AlphaFold predicted model PDB URL for  P21397 : https://alphafold.ebi.ac.uk/files/AF-P21397-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P21397 .pdb
# AlphaFold predicted model PDB URL for  P10599 : https://alphafold.ebi.ac.uk/files/AF-P10599-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P10599 .pdb
# AlphaFold predicted model PDB URL for  P60174 : https://alphafold.ebi.ac.uk/files/AF-P60174-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P60174 .pdb
# AlphaFold predicted model PDB URL for  P09211 : https://alphafold.ebi.ac.uk/files/AF-P09211-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P09211 .pdb
# AlphaFold predicted model PDB URL for  P00374 : https://alphafold.ebi.ac.uk/files/AF-P00374-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00374 .pdb
# AlphaFold predicted model PDB URL for  P61823 : https://alphafold.ebi.ac.uk/files/AF-P61823-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P61823 .pdb
# AlphaFold predicted model PDB URL for  P54136 : https://alphafold.ebi.ac.uk/files/AF-P54136-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P54136 .pdb
# AlphaFold predicted model PDB URL for  P13807 : https://alphafold.ebi.ac.uk/files/AF-P13807-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P13807 .pdb
# AlphaFold predicted model PDB URL for  P46951 : https://alphafold.ebi.ac.uk/files/AF-P46951-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P46951 .pdb
# AlphaFold predicted model PDB URL for  P52209 : https://alphafold.ebi.ac.uk/files/AF-P52209-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P52209 .pdb
# AlphaFold predicted model PDB URL for  P15104 : https://alphafold.ebi.ac.uk/files/AF-P15104-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P15104 .pdb
# AlphaFold predicted model PDB URL for  P09083 : https://alphafold.ebi.ac.uk/files/AF-P09083-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P09083 .pdb
# AlphaFold predicted model PDB URL for  P51648 : https://alphafold.ebi.ac.uk/files/AF-P51648-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P51648 .pdb
# AlphaFold predicted model PDB URL for  P09172 : https://alphafold.ebi.ac.uk/files/AF-P09172-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P09172 .pdb
# AlphaFold predicted model PDB URL for  P00791 : https://alphafold.ebi.ac.uk/files/AF-P00791-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00791 .pdb
# AlphaFold predicted model PDB URL for  P06276 : https://alphafold.ebi.ac.uk/files/AF-P06276-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P06276 .pdb
# AlphaFold predicted model PDB URL for  P00639 : https://alphafold.ebi.ac.uk/files/AF-P00639-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00639 .pdb
# AlphaFold predicted model PDB URL for  P11388 : https://alphafold.ebi.ac.uk/files/AF-P11388-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P11388 .pdb
# AlphaFold predicted model PDB URL for  P14174 : https://alphafold.ebi.ac.uk/files/AF-P14174-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P14174 .pdb
# AlphaFold predicted model PDB URL for  P07374 : https://alphafold.ebi.ac.uk/files/AF-P07374-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P07374 .pdb
# AlphaFold predicted model PDB URL for  P62877 : https://alphafold.ebi.ac.uk/files/AF-P62877-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P62877 .pdb
# AlphaFold predicted model PDB URL for  P00760 : https://alphafold.ebi.ac.uk/files/AF-P00760-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00760 .pdb
# AlphaFold predicted model PDB URL for  P16233 : https://alphafold.ebi.ac.uk/files/AF-P16233-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P16233 .pdb
# AlphaFold predicted model PDB URL for  P49917 : https://alphafold.ebi.ac.uk/files/AF-P49917-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P49917 .pdb
# AlphaFold predicted model PDB URL for  P00352 : https://alphafold.ebi.ac.uk/files/AF-P00352-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00352 .pdb
# AlphaFold predicted model PDB URL for  P32245 : https://alphafold.ebi.ac.uk/files/AF-P32245-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P32245 .pdb
# AlphaFold predicted model PDB URL for  P11498 : https://alphafold.ebi.ac.uk/files/AF-P11498-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P11498 .pdb
# AlphaFold predicted model PDB URL for  P00929 : https://alphafold.ebi.ac.uk/files/AF-P00929-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00929 .pdb
# AlphaFold predicted model PDB URL for  P00519 : https://alphafold.ebi.ac.uk/files/AF-P00519-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00519 .pdb
# AlphaFold predicted model PDB URL for  P49327 : https://alphafold.ebi.ac.uk/files/AF-P49327-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P49327 .pdb
# AlphaFold predicted model PDB URL for  P00505 : https://alphafold.ebi.ac.uk/files/AF-P00505-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00505 .pdb
# AlphaFold predicted model PDB URL for  P04040 : https://alphafold.ebi.ac.uk/files/AF-P04040-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P04040 .pdb
# AlphaFold predicted model PDB URL for  Q8W3K0 : https://alphafold.ebi.ac.uk/files/AF-Q8W3K0-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ Q8W3K0 .pdb
# AlphaFold predicted model PDB URL for  P00579 : https://alphafold.ebi.ac.uk/files/AF-P00579-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00579 .pdb
# AlphaFold predicted model PDB URL for  P00940 : https://alphafold.ebi.ac.uk/files/AF-P00940-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00940 .pdb
# AlphaFold predicted model PDB URL for  P11926 : https://alphafold.ebi.ac.uk/files/AF-P11926-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P11926 .pdb
# AlphaFold predicted model PDB URL for  P00441 : https://alphafold.ebi.ac.uk/files/AF-P00441-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00441 .pdb
# Failed to retrieve data for UniProt ID  P07203 . Status code: 404
# AlphaFold predicted model PDB URL for  P06744 : https://alphafold.ebi.ac.uk/files/AF-P06744-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P06744 .pdb
# AlphaFold predicted model PDB URL for  P49247 : https://alphafold.ebi.ac.uk/files/AF-P49247-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P49247 .pdb
# AlphaFold predicted model PDB URL for  P00734 : https://alphafold.ebi.ac.uk/files/AF-P00734-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00734 .pdb
# AlphaFold predicted model PDB URL for  P00700 : https://alphafold.ebi.ac.uk/files/AF-P00700-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P00700 .pdb
# AlphaFold predicted model PDB URL for  P03956 : https://alphafold.ebi.ac.uk/files/AF-P03956-F1-model_v4.pdb
# PDB file saved as new_enzymes_pdb/ P03956 .pdb

# %% [markdown]
# ### Fetch PDB for TF

# %%
# Fetch and visualize structures for all the given UniProt IDs

tf_pdb = fetch_pdb_from_alphafold(transcript_factor['UniProt ID'],'TFs_pdb')
# Out:
# AlphaFold predicted model PDB URL for P04637: https://alphafold.ebi.ac.uk/files/AF-P04637-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P04637.pdb
# AlphaFold predicted model PDB URL for P15063: https://alphafold.ebi.ac.uk/files/AF-P15063-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P15063.pdb
# AlphaFold predicted model PDB URL for P08047: https://alphafold.ebi.ac.uk/files/AF-P08047-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P08047.pdb
# AlphaFold predicted model PDB URL for Q15672: https://alphafold.ebi.ac.uk/files/AF-Q15672-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q15672.pdb
# AlphaFold predicted model PDB URL for P03372: https://alphafold.ebi.ac.uk/files/AF-P03372-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P03372.pdb
# AlphaFold predicted model PDB URL for P15976: https://alphafold.ebi.ac.uk/files/AF-P15976-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P15976.pdb
# AlphaFold predicted model PDB URL for P43694: https://alphafold.ebi.ac.uk/files/AF-P43694-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P43694.pdb
# AlphaFold predicted model PDB URL for P41235: https://alphafold.ebi.ac.uk/files/AF-P41235-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P41235.pdb
# AlphaFold predicted model PDB URL for O75461: https://alphafold.ebi.ac.uk/files/AF-O75461-F1-model_v4.pdb
# PDB file saved as TFs_pdb/O75461.pdb
# AlphaFold predicted model PDB URL for P05412: https://alphafold.ebi.ac.uk/files/AF-P05412-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P05412.pdb
# AlphaFold predicted model PDB URL for P15336: https://alphafold.ebi.ac.uk/files/AF-P15336-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P15336.pdb
# AlphaFold predicted model PDB URL for P49715: https://alphafold.ebi.ac.uk/files/AF-P49715-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P49715.pdb
# AlphaFold predicted model PDB URL for O43524: https://alphafold.ebi.ac.uk/files/AF-O43524-F1-model_v4.pdb
# PDB file saved as TFs_pdb/O43524.pdb
# AlphaFold predicted model PDB URL for P48431: https://alphafold.ebi.ac.uk/files/AF-P48431-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P48431.pdb
# AlphaFold predicted model PDB URL for P40763: https://alphafold.ebi.ac.uk/files/AF-P40763-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P40763.pdb
# AlphaFold predicted model PDB URL for P26367: https://alphafold.ebi.ac.uk/files/AF-P26367-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P26367.pdb
# AlphaFold predicted model PDB URL for Q13469: https://alphafold.ebi.ac.uk/files/AF-Q13469-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q13469.pdb
# AlphaFold predicted model PDB URL for P19838: https://alphafold.ebi.ac.uk/files/AF-P19838-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P19838.pdb
# AlphaFold predicted model PDB URL for Q06413: https://alphafold.ebi.ac.uk/files/AF-Q06413-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q06413.pdb
# AlphaFold predicted model PDB URL for Q9NQB0: https://alphafold.ebi.ac.uk/files/AF-Q9NQB0-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9NQB0.pdb
# AlphaFold predicted model PDB URL for P37275: https://alphafold.ebi.ac.uk/files/AF-P37275-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P37275.pdb
# AlphaFold predicted model PDB URL for O15350: https://alphafold.ebi.ac.uk/files/AF-O15350-F1-model_v4.pdb
# PDB file saved as TFs_pdb/O15350.pdb
# AlphaFold predicted model PDB URL for P16220: https://alphafold.ebi.ac.uk/files/AF-P16220-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P16220.pdb
# AlphaFold predicted model PDB URL for Q9BZS1: https://alphafold.ebi.ac.uk/files/AF-Q9BZS1-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9BZS1.pdb
# AlphaFold predicted model PDB URL for P01106: https://alphafold.ebi.ac.uk/files/AF-P01106-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P01106.pdb
# AlphaFold predicted model PDB URL for P41182: https://alphafold.ebi.ac.uk/files/AF-P41182-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P41182.pdb
# AlphaFold predicted model PDB URL for Q07869: https://alphafold.ebi.ac.uk/files/AF-Q07869-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q07869.pdb
# AlphaFold predicted model PDB URL for O43474: https://alphafold.ebi.ac.uk/files/AF-O43474-F1-model_v4.pdb
# PDB file saved as TFs_pdb/O43474.pdb
# AlphaFold predicted model PDB URL for P42224: https://alphafold.ebi.ac.uk/files/AF-P42224-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P42224.pdb
# AlphaFold predicted model PDB URL for P19793: https://alphafold.ebi.ac.uk/files/AF-P19793-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P19793.pdb
# AlphaFold predicted model PDB URL for Q15796: https://alphafold.ebi.ac.uk/files/AF-Q15796-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q15796.pdb
# AlphaFold predicted model PDB URL for Q13485: https://alphafold.ebi.ac.uk/files/AF-Q13485-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q13485.pdb
# AlphaFold predicted model PDB URL for P10275: https://alphafold.ebi.ac.uk/files/AF-P10275-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P10275.pdb
# AlphaFold predicted model PDB URL for Q9NQB0: https://alphafold.ebi.ac.uk/files/AF-Q9NQB0-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9NQB0.pdb
# AlphaFold predicted model PDB URL for P48436: https://alphafold.ebi.ac.uk/files/AF-P48436-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P48436.pdb
# AlphaFold predicted model PDB URL for Q16665: https://alphafold.ebi.ac.uk/files/AF-Q16665-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q16665.pdb
# AlphaFold predicted model PDB URL for P18146: https://alphafold.ebi.ac.uk/files/AF-P18146-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P18146.pdb
# AlphaFold predicted model PDB URL for P15923: https://alphafold.ebi.ac.uk/files/AF-P15923-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P15923.pdb
# AlphaFold predicted model PDB URL for P01100: https://alphafold.ebi.ac.uk/files/AF-P01100-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P01100.pdb
# AlphaFold predicted model PDB URL for P32519: https://alphafold.ebi.ac.uk/files/AF-P32519-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P32519.pdb
# AlphaFold predicted model PDB URL for P08151: https://alphafold.ebi.ac.uk/files/AF-P08151-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P08151.pdb
# AlphaFold predicted model PDB URL for Q14653: https://alphafold.ebi.ac.uk/files/AF-Q14653-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q14653.pdb
# AlphaFold predicted model PDB URL for P19532: https://alphafold.ebi.ac.uk/files/AF-P19532-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P19532.pdb
# AlphaFold predicted model PDB URL for P17861: https://alphafold.ebi.ac.uk/files/AF-P17861-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P17861.pdb
# AlphaFold predicted model PDB URL for P14921: https://alphafold.ebi.ac.uk/files/AF-P14921-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P14921.pdb
# AlphaFold predicted model PDB URL for Q9H334: https://alphafold.ebi.ac.uk/files/AF-Q9H334-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9H334.pdb
# AlphaFold predicted model PDB URL for P52952: https://alphafold.ebi.ac.uk/files/AF-P52952-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P52952.pdb
# AlphaFold predicted model PDB URL for P40424: https://alphafold.ebi.ac.uk/files/AF-P40424-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P40424.pdb
# AlphaFold predicted model PDB URL for Q9Y5Q3: https://alphafold.ebi.ac.uk/files/AF-Q9Y5Q3-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9Y5Q3.pdb
# AlphaFold predicted model PDB URL for P28347: https://alphafold.ebi.ac.uk/files/AF-P28347-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P28347.pdb
# AlphaFold predicted model PDB URL for P10589: https://alphafold.ebi.ac.uk/files/AF-P10589-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P10589.pdb
# AlphaFold predicted model PDB URL for Q04206: https://alphafold.ebi.ac.uk/files/AF-Q04206-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q04206.pdb
# AlphaFold predicted model PDB URL for P35869: https://alphafold.ebi.ac.uk/files/AF-P35869-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P35869.pdb
# AlphaFold predicted model PDB URL for O15409: https://alphafold.ebi.ac.uk/files/AF-O15409-F1-model_v4.pdb
# PDB file saved as TFs_pdb/O15409.pdb
# AlphaFold predicted model PDB URL for Q92985: https://alphafold.ebi.ac.uk/files/AF-Q92985-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q92985.pdb
# AlphaFold predicted model PDB URL for P15172: https://alphafold.ebi.ac.uk/files/AF-P15172-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P15172.pdb
# AlphaFold predicted model PDB URL for P23769: https://alphafold.ebi.ac.uk/files/AF-P23769-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P23769.pdb
# AlphaFold predicted model PDB URL for Q01860: https://alphafold.ebi.ac.uk/files/AF-Q01860-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q01860.pdb
# AlphaFold predicted model PDB URL for O43623: https://alphafold.ebi.ac.uk/files/AF-O43623-F1-model_v4.pdb
# PDB file saved as TFs_pdb/O43623.pdb
# AlphaFold predicted model PDB URL for P50549: https://alphafold.ebi.ac.uk/files/AF-P50549-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P50549.pdb
# AlphaFold predicted model PDB URL for Q13133: https://alphafold.ebi.ac.uk/files/AF-Q13133-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q13133.pdb
# AlphaFold predicted model PDB URL for P84022: https://alphafold.ebi.ac.uk/files/AF-P84022-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P84022.pdb
# AlphaFold predicted model PDB URL for Q12778: https://alphafold.ebi.ac.uk/files/AF-Q12778-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q12778.pdb
# AlphaFold predicted model PDB URL for Q9Y261: https://alphafold.ebi.ac.uk/files/AF-Q9Y261-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9Y261.pdb
# AlphaFold predicted model PDB URL for O75626: https://alphafold.ebi.ac.uk/files/AF-O75626-F1-model_v4.pdb
# PDB file saved as TFs_pdb/O75626.pdb
# AlphaFold predicted model PDB URL for Q9UJQ4: https://alphafold.ebi.ac.uk/files/AF-Q9UJQ4-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9UJQ4.pdb
# AlphaFold predicted model PDB URL for Q13568: https://alphafold.ebi.ac.uk/files/AF-Q13568-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q13568.pdb
# AlphaFold predicted model PDB URL for Q9ULX6: https://alphafold.ebi.ac.uk/files/AF-Q9ULX6-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9ULX6.pdb
# AlphaFold predicted model PDB URL for P15036: https://alphafold.ebi.ac.uk/files/AF-P15036-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P15036.pdb
# AlphaFold predicted model PDB URL for Q9UJU2: https://alphafold.ebi.ac.uk/files/AF-Q9UJU2-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9UJU2.pdb
# AlphaFold predicted model PDB URL for P31269: https://alphafold.ebi.ac.uk/files/AF-P31269-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P31269.pdb
# AlphaFold predicted model PDB URL for P20226: https://alphafold.ebi.ac.uk/files/AF-P20226-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P20226.pdb
# AlphaFold predicted model PDB URL for Q14814: https://alphafold.ebi.ac.uk/files/AF-Q14814-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q14814.pdb
# AlphaFold predicted model PDB URL for P23771: https://alphafold.ebi.ac.uk/files/AF-P23771-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P23771.pdb
# AlphaFold predicted model PDB URL for Q9H2X9: https://alphafold.ebi.ac.uk/files/AF-Q9H2X9-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9H2X9.pdb
# AlphaFold predicted model PDB URL for Q99081: https://alphafold.ebi.ac.uk/files/AF-Q99081-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q99081.pdb
# AlphaFold predicted model PDB URL for Q06330: https://alphafold.ebi.ac.uk/files/AF-Q06330-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q06330.pdb
# AlphaFold predicted model PDB URL for P42229: https://alphafold.ebi.ac.uk/files/AF-P42229-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P42229.pdb
# AlphaFold predicted model PDB URL for P15036: https://alphafold.ebi.ac.uk/files/AF-P15036-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P15036.pdb
# AlphaFold predicted model PDB URL for P17275: https://alphafold.ebi.ac.uk/files/AF-P17275-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P17275.pdb
# AlphaFold predicted model PDB URL for P20265: https://alphafold.ebi.ac.uk/files/AF-P20265-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P20265.pdb
# AlphaFold predicted model PDB URL for O75030: https://alphafold.ebi.ac.uk/files/AF-O75030-F1-model_v4.pdb
# PDB file saved as TFs_pdb/O75030.pdb
# AlphaFold predicted model PDB URL for P37231: https://alphafold.ebi.ac.uk/files/AF-P37231-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P37231.pdb
# AlphaFold predicted model PDB URL for Q00653: https://alphafold.ebi.ac.uk/files/AF-Q00653-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q00653.pdb
# AlphaFold predicted model PDB URL for Q9UBC2: https://alphafold.ebi.ac.uk/files/AF-Q9UBC2-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9UBC2.pdb
# AlphaFold predicted model PDB URL for Q08050: https://alphafold.ebi.ac.uk/files/AF-Q08050-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q08050.pdb
# AlphaFold predicted model PDB URL for P41212: https://alphafold.ebi.ac.uk/files/AF-P41212-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P41212.pdb
# AlphaFold predicted model PDB URL for P17947: https://alphafold.ebi.ac.uk/files/AF-P17947-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P17947.pdb
# Failed to retrieve data for UniProt ID O15413. Status code: 404
# AlphaFold predicted model PDB URL for P35398: https://alphafold.ebi.ac.uk/files/AF-P35398-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P35398.pdb
# AlphaFold predicted model PDB URL for Q9BZS1: https://alphafold.ebi.ac.uk/files/AF-Q9BZS1-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q9BZS1.pdb
# AlphaFold predicted model PDB URL for Q13761: https://alphafold.ebi.ac.uk/files/AF-Q13761-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q13761.pdb
# AlphaFold predicted model PDB URL for P56693: https://alphafold.ebi.ac.uk/files/AF-P56693-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P56693.pdb
# AlphaFold predicted model PDB URL for P16220: https://alphafold.ebi.ac.uk/files/AF-P16220-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P16220.pdb
# AlphaFold predicted model PDB URL for Q16621: https://alphafold.ebi.ac.uk/files/AF-Q16621-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q16621.pdb
# AlphaFold predicted model PDB URL for P10914: https://alphafold.ebi.ac.uk/files/AF-P10914-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P10914.pdb
# AlphaFold predicted model PDB URL for Q04864: https://alphafold.ebi.ac.uk/files/AF-Q04864-F1-model_v4.pdb
# PDB file saved as TFs_pdb/Q04864.pdb
# AlphaFold predicted model PDB URL for P11831: https://alphafold.ebi.ac.uk/files/AF-P11831-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P11831.pdb
# AlphaFold predicted model PDB URL for P22736: https://alphafold.ebi.ac.uk/files/AF-P22736-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P22736.pdb
# AlphaFold predicted model PDB URL for P17676: https://alphafold.ebi.ac.uk/files/AF-P17676-F1-model_v4.pdb
# PDB file saved as TFs_pdb/P17676.pdb

# %%
# Fetch and visualize structures for all the given UniProt IDs

new_tf_pdb = fetch_pdb_from_alphafold(tf_90['TF_ID'],'new_TFs_pdb')
# Out:
# AlphaFold predicted model PDB URL for  P22736 : https://alphafold.ebi.ac.uk/files/AF-P22736-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P22736 .pdb
# AlphaFold predicted model PDB URL for  Q9H334 : https://alphafold.ebi.ac.uk/files/AF-Q9H334-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q9H334 .pdb
# AlphaFold predicted model PDB URL for  P48436 : https://alphafold.ebi.ac.uk/files/AF-P48436-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P48436 .pdb
# AlphaFold predicted model PDB URL for  P28347 : https://alphafold.ebi.ac.uk/files/AF-P28347-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P28347 .pdb
# AlphaFold predicted model PDB URL for  Q06330 : https://alphafold.ebi.ac.uk/files/AF-Q06330-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q06330 .pdb
# AlphaFold predicted model PDB URL for  P03372 : https://alphafold.ebi.ac.uk/files/AF-P03372-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P03372 .pdb
# AlphaFold predicted model PDB URL for  P15036 : https://alphafold.ebi.ac.uk/files/AF-P15036-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P15036 .pdb
# AlphaFold predicted model PDB URL for  P50549 : https://alphafold.ebi.ac.uk/files/AF-P50549-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P50549 .pdb
# AlphaFold predicted model PDB URL for  P10275 : https://alphafold.ebi.ac.uk/files/AF-P10275-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P10275 .pdb
# AlphaFold predicted model PDB URL for  Q13485 : https://alphafold.ebi.ac.uk/files/AF-Q13485-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q13485 .pdb
# AlphaFold predicted model PDB URL for  P56693 : https://alphafold.ebi.ac.uk/files/AF-P56693-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P56693 .pdb
# AlphaFold predicted model PDB URL for  Q00653 : https://alphafold.ebi.ac.uk/files/AF-Q00653-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q00653 .pdb
# AlphaFold predicted model PDB URL for  P15172 : https://alphafold.ebi.ac.uk/files/AF-P15172-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P15172 .pdb
# AlphaFold predicted model PDB URL for  P37231 : https://alphafold.ebi.ac.uk/files/AF-P37231-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P37231 .pdb
# AlphaFold predicted model PDB URL for  P15976 : https://alphafold.ebi.ac.uk/files/AF-P15976-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P15976 .pdb
# AlphaFold predicted model PDB URL for  P11831 : https://alphafold.ebi.ac.uk/files/AF-P11831-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P11831 .pdb
# AlphaFold predicted model PDB URL for  Q92985 : https://alphafold.ebi.ac.uk/files/AF-Q92985-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q92985 .pdb
# AlphaFold predicted model PDB URL for  P40763 : https://alphafold.ebi.ac.uk/files/AF-P40763-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P40763 .pdb
# AlphaFold predicted model PDB URL for  P26367 : https://alphafold.ebi.ac.uk/files/AF-P26367-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P26367 .pdb
# AlphaFold predicted model PDB URL for  Q14653 : https://alphafold.ebi.ac.uk/files/AF-Q14653-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q14653 .pdb
# AlphaFold predicted model PDB URL for  Q9UJQ4 : https://alphafold.ebi.ac.uk/files/AF-Q9UJQ4-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q9UJQ4 .pdb
# AlphaFold predicted model PDB URL for  P19838 : https://alphafold.ebi.ac.uk/files/AF-P19838-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P19838 .pdb
# AlphaFold predicted model PDB URL for  P41235 : https://alphafold.ebi.ac.uk/files/AF-P41235-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P41235 .pdb
# AlphaFold predicted model PDB URL for  Q9ULX6 : https://alphafold.ebi.ac.uk/files/AF-Q9ULX6-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q9ULX6 .pdb
# AlphaFold predicted model PDB URL for  P35398 : https://alphafold.ebi.ac.uk/files/AF-P35398-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P35398 .pdb
# AlphaFold predicted model PDB URL for  P15923 : https://alphafold.ebi.ac.uk/files/AF-P15923-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P15923 .pdb
# AlphaFold predicted model PDB URL for  Q04864 : https://alphafold.ebi.ac.uk/files/AF-Q04864-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q04864 .pdb
# AlphaFold predicted model PDB URL for  O75030 : https://alphafold.ebi.ac.uk/files/AF-O75030-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ O75030 .pdb
# AlphaFold predicted model PDB URL for  Q9Y261 : https://alphafold.ebi.ac.uk/files/AF-Q9Y261-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q9Y261 .pdb
# AlphaFold predicted model PDB URL for  Q9UJU2 : https://alphafold.ebi.ac.uk/files/AF-Q9UJU2-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q9UJU2 .pdb
# AlphaFold predicted model PDB URL for  P40424 : https://alphafold.ebi.ac.uk/files/AF-P40424-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P40424 .pdb
# AlphaFold predicted model PDB URL for  O43524 : https://alphafold.ebi.ac.uk/files/AF-O43524-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ O43524 .pdb
# AlphaFold predicted model PDB URL for  Q13761 : https://alphafold.ebi.ac.uk/files/AF-Q13761-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q13761 .pdb
# AlphaFold predicted model PDB URL for  Q9Y5Q3 : https://alphafold.ebi.ac.uk/files/AF-Q9Y5Q3-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q9Y5Q3 .pdb
# AlphaFold predicted model PDB URL for  P19532 : https://alphafold.ebi.ac.uk/files/AF-P19532-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P19532 .pdb
# AlphaFold predicted model PDB URL for  P49715 : https://alphafold.ebi.ac.uk/files/AF-P49715-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P49715 .pdb
# AlphaFold predicted model PDB URL for  O43474 : https://alphafold.ebi.ac.uk/files/AF-O43474-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ O43474 .pdb
# AlphaFold predicted model PDB URL for  P23769 : https://alphafold.ebi.ac.uk/files/AF-P23769-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P23769 .pdb
# AlphaFold predicted model PDB URL for  Q16621 : https://alphafold.ebi.ac.uk/files/AF-Q16621-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q16621 .pdb
# AlphaFold predicted model PDB URL for  P20226 : https://alphafold.ebi.ac.uk/files/AF-P20226-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P20226 .pdb
# AlphaFold predicted model PDB URL for  P32519 : https://alphafold.ebi.ac.uk/files/AF-P32519-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P32519 .pdb
# AlphaFold predicted model PDB URL for  Q9NQB0 : https://alphafold.ebi.ac.uk/files/AF-Q9NQB0-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q9NQB0 .pdb
# AlphaFold predicted model PDB URL for  P15063 : https://alphafold.ebi.ac.uk/files/AF-P15063-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P15063 .pdb
# AlphaFold predicted model PDB URL for  P01100 : https://alphafold.ebi.ac.uk/files/AF-P01100-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P01100 .pdb
# AlphaFold predicted model PDB URL for  P18146 : https://alphafold.ebi.ac.uk/files/AF-P18146-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P18146 .pdb
# AlphaFold predicted model PDB URL for  P08151 : https://alphafold.ebi.ac.uk/files/AF-P08151-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P08151 .pdb
# AlphaFold predicted model PDB URL for  P01106 : https://alphafold.ebi.ac.uk/files/AF-P01106-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P01106 .pdb
# AlphaFold predicted model PDB URL for  P10914 : https://alphafold.ebi.ac.uk/files/AF-P10914-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P10914 .pdb
# AlphaFold predicted model PDB URL for  O43623 : https://alphafold.ebi.ac.uk/files/AF-O43623-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ O43623 .pdb
# AlphaFold predicted model PDB URL for  Q13568 : https://alphafold.ebi.ac.uk/files/AF-Q13568-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q13568 .pdb
# AlphaFold predicted model PDB URL for  P42224 : https://alphafold.ebi.ac.uk/files/AF-P42224-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P42224 .pdb
# AlphaFold predicted model PDB URL for  P41182 : https://alphafold.ebi.ac.uk/files/AF-P41182-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P41182 .pdb
# AlphaFold predicted model PDB URL for  Q07869 : https://alphafold.ebi.ac.uk/files/AF-Q07869-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q07869 .pdb
# Failed to retrieve data for UniProt ID  O15413 . Status code: 404
# AlphaFold predicted model PDB URL for  P31269 : https://alphafold.ebi.ac.uk/files/AF-P31269-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P31269 .pdb
# AlphaFold predicted model PDB URL for  P04637 : https://alphafold.ebi.ac.uk/files/AF-P04637-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P04637 .pdb
# AlphaFold predicted model PDB URL for  Q08050 : https://alphafold.ebi.ac.uk/files/AF-Q08050-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q08050 .pdb
# AlphaFold predicted model PDB URL for  Q16665 : https://alphafold.ebi.ac.uk/files/AF-Q16665-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q16665 .pdb
# AlphaFold predicted model PDB URL for  Q99081 : https://alphafold.ebi.ac.uk/files/AF-Q99081-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q99081 .pdb
# AlphaFold predicted model PDB URL for  Q13133 : https://alphafold.ebi.ac.uk/files/AF-Q13133-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q13133 .pdb
# AlphaFold predicted model PDB URL for  P05412 : https://alphafold.ebi.ac.uk/files/AF-P05412-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P05412 .pdb
# AlphaFold predicted model PDB URL for  P10589 : https://alphafold.ebi.ac.uk/files/AF-P10589-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P10589 .pdb
# AlphaFold predicted model PDB URL for  Q04206 : https://alphafold.ebi.ac.uk/files/AF-Q04206-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q04206 .pdb
# AlphaFold predicted model PDB URL for  Q9H2X9 : https://alphafold.ebi.ac.uk/files/AF-Q9H2X9-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q9H2X9 .pdb
# AlphaFold predicted model PDB URL for  P84022 : https://alphafold.ebi.ac.uk/files/AF-P84022-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P84022 .pdb
# AlphaFold predicted model PDB URL for  P17275 : https://alphafold.ebi.ac.uk/files/AF-P17275-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P17275 .pdb
# AlphaFold predicted model PDB URL for  Q12778 : https://alphafold.ebi.ac.uk/files/AF-Q12778-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q12778 .pdb
# AlphaFold predicted model PDB URL for  P17676 : https://alphafold.ebi.ac.uk/files/AF-P17676-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P17676 .pdb
# AlphaFold predicted model PDB URL for  P17947 : https://alphafold.ebi.ac.uk/files/AF-P17947-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P17947 .pdb
# AlphaFold predicted model PDB URL for  O75626 : https://alphafold.ebi.ac.uk/files/AF-O75626-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ O75626 .pdb
# AlphaFold predicted model PDB URL for  P15336 : https://alphafold.ebi.ac.uk/files/AF-P15336-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P15336 .pdb
# AlphaFold predicted model PDB URL for  P17861 : https://alphafold.ebi.ac.uk/files/AF-P17861-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P17861 .pdb
# AlphaFold predicted model PDB URL for  O75461 : https://alphafold.ebi.ac.uk/files/AF-O75461-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ O75461 .pdb
# AlphaFold predicted model PDB URL for  P42229 : https://alphafold.ebi.ac.uk/files/AF-P42229-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P42229 .pdb
# AlphaFold predicted model PDB URL for  Q13469 : https://alphafold.ebi.ac.uk/files/AF-Q13469-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q13469 .pdb
# AlphaFold predicted model PDB URL for  P52952 : https://alphafold.ebi.ac.uk/files/AF-P52952-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P52952 .pdb
# AlphaFold predicted model PDB URL for  Q06413 : https://alphafold.ebi.ac.uk/files/AF-Q06413-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q06413 .pdb
# AlphaFold predicted model PDB URL for  Q15796 : https://alphafold.ebi.ac.uk/files/AF-Q15796-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q15796 .pdb
# AlphaFold predicted model PDB URL for  P37275 : https://alphafold.ebi.ac.uk/files/AF-P37275-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P37275 .pdb
# AlphaFold predicted model PDB URL for  O15409 : https://alphafold.ebi.ac.uk/files/AF-O15409-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ O15409 .pdb
# AlphaFold predicted model PDB URL for  P14921 : https://alphafold.ebi.ac.uk/files/AF-P14921-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P14921 .pdb
# AlphaFold predicted model PDB URL for  P19793 : https://alphafold.ebi.ac.uk/files/AF-P19793-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P19793 .pdb
# AlphaFold predicted model PDB URL for  P35869 : https://alphafold.ebi.ac.uk/files/AF-P35869-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P35869 .pdb
# AlphaFold predicted model PDB URL for  Q14814 : https://alphafold.ebi.ac.uk/files/AF-Q14814-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q14814 .pdb
# AlphaFold predicted model PDB URL for  P48431 : https://alphafold.ebi.ac.uk/files/AF-P48431-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P48431 .pdb
# AlphaFold predicted model PDB URL for  O15350 : https://alphafold.ebi.ac.uk/files/AF-O15350-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ O15350 .pdb
# AlphaFold predicted model PDB URL for  P16220 : https://alphafold.ebi.ac.uk/files/AF-P16220-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P16220 .pdb
# AlphaFold predicted model PDB URL for  Q15672 : https://alphafold.ebi.ac.uk/files/AF-Q15672-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ Q15672 .pdb
# AlphaFold predicted model PDB URL for  P43694 : https://alphafold.ebi.ac.uk/files/AF-P43694-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P43694 .pdb
# AlphaFold predicted model PDB URL for  P08047 : https://alphafold.ebi.ac.uk/files/AF-P08047-F1-model_v4.pdb
# PDB file saved as new_TFs_pdb/ P08047 .pdb

# %% [markdown]
# ### Calculate Fractal Dimension

# %%
# Step 1: Parse the PDB file and extract atom coordinates
def extract_coordinates(pdb_file):
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure("protein", pdb_file)

    atom_coordinates = []
    for atom in structure.get_atoms():
        atom_coordinates.append(atom.get_coord())

    return np.array(atom_coordinates)

# Step 2: Calculate the bounding box for the protein structure
def calculate_bounding_box(coords):
    min_coords = coords.min(axis=0)
    max_coords = coords.max(axis=0)
    return min_coords, max_coords

# Step 3: Box counting function
def box_counting(coords, min_coords, max_coords, grid_size):
    n_boxes = np.ceil((max_coords - min_coords) / grid_size).astype(int)
    occupied_boxes = set()

    # Assign atoms to grid cells (boxes)
    for coord in coords:
        box_idx = tuple(((coord - min_coords) // grid_size).astype(int))
        occupied_boxes.add(box_idx)

    return len(occupied_boxes)

# Step 4: Perform box counting over different grid sizes
def perform_box_counting(coords, min_coords, max_coords):
    # Calculate the largest bounding box dimension (max_length)
    max_length = np.max(max_coords - min_coords)  # Get the largest bounding box dimension

    # Generate grid sizes from max_length/100 to max_length/2, with 15 grid sizes
    grid_sizes = np.logspace(np.log10(max_length/100), np.log10(max_length/2), num=15)

    occupied_boxes_per_grid = []
    for grid_size in grid_sizes:
        occupied_boxes = box_counting(coords, min_coords, max_coords, grid_size)
        occupied_boxes_per_grid.append(occupied_boxes)
    
    return grid_sizes, occupied_boxes_per_grid

# Step 5: Calculate and plot fractal dimension
def calculate_fractal_dimension(grid_sizes, occupied_boxes_per_grid):
    log_occupied_boxes = np.log(occupied_boxes_per_grid)
    log_inverse_grid_size = np.log(1 / grid_sizes)

    # Perform linear regression on log-log data to find the slope (fractal dimension)
    slope, intercept, r_value, p_value, std_err = linregress(log_inverse_grid_size, log_occupied_boxes)
    fractal_dimension = slope
    print(f"Estimated Fractal Dimension: {fractal_dimension:.4f}")
    return fractal_dimension

# Step 6: Main function to estimate the fractal dimension of a protein structure
def estimate_fractal_dimension(pdb_file):
    # Extract coordinates
    coords = extract_coordinates(pdb_file)

    # Calculate bounding box
    min_coords, max_coords = calculate_bounding_box(coords)

    # Perform box counting
    grid_sizes, occupied_boxes_per_grid = perform_box_counting(coords, min_coords, max_coords)

    # Calculate and plot fractal dimension
    fractal_dimension = calculate_fractal_dimension(grid_sizes, occupied_boxes_per_grid)

    return fractal_dimension

# %% [markdown]
# ## Fractal Dimension For all Enzymes

# %%
def process_pdb_files(folder_name):

    # Initialize an empty list to store enzyme names and fractal dimensions
    data = []

    # Loop over all PDB files in the folder
    for pdb_file in os.listdir(folder_name):
        if pdb_file.endswith(".pdb"):
            enzyme_name = pdb_file.split('.')[0]  # Extract enzyme name from the file name
            
            # Construct the full path to the PDB file
            pdb_path = os.path.join(folder_name, pdb_file)

            try:
                # Call your custom function to estimate fractal dimension for the pdb file
                fractal_dimension = estimate_fractal_dimension(pdb_path)
                
                # Append the result to the data list
                data.append([enzyme_name, fractal_dimension])

            except Exception as e:
                print(f"An error occurred while processing {pdb_file}: {e}")

    # Create a Pandas DataFrame with enzyme names and fractal dimensions
    df = pd.DataFrame(data, columns=['Enzyme Name', 'Fractal Dimension'])
    
    # Optionally, save the DataFrame to a CSV file
    output_csv = os.path.join(folder_name, 'fractal_dimensions.csv')
    df.to_csv(output_csv, index=False)
    print(f"Results saved to {output_csv}")

    return df

# Example usage: assuming 'pdb_files' folder contains downloaded PDB files
fractal_dimension_df = process_pdb_files('enzymes_pdb')
print(fractal_dimension_df)
# Out:
# Estimated Fractal Dimension: 1.6760
# Estimated Fractal Dimension: 2.0477
# Estimated Fractal Dimension: 1.6463
# Estimated Fractal Dimension: 1.4035
# Estimated Fractal Dimension: 1.6503
# Estimated Fractal Dimension: 1.5137
# Estimated Fractal Dimension: 1.9091
# Estimated Fractal Dimension: 1.7295
# Estimated Fractal Dimension: 1.6001
# Estimated Fractal Dimension: 1.5212
# Estimated Fractal Dimension: 1.1916
# Estimated Fractal Dimension: 1.5139
# Estimated Fractal Dimension: 1.8274
# Estimated Fractal Dimension: 1.5851
# Estimated Fractal Dimension: 1.7901
# Estimated Fractal Dimension: 1.6742
# Estimated Fractal Dimension: 1.8057
# Estimated Fractal Dimension: 1.3971
# Estimated Fractal Dimension: 1.8491
# Estimated Fractal Dimension: 1.7238
# Estimated Fractal Dimension: 1.6990
# Estimated Fractal Dimension: 1.8420
# Estimated Fractal Dimension: 1.6850
# Estimated Fractal Dimension: 1.7378
# Estimated Fractal Dimension: 1.5702
# Estimated Fractal Dimension: 1.4946
# Estimated Fractal Dimension: 1.7023
# Estimated Fractal Dimension: 1.7999
# Estimated Fractal Dimension: 1.3416
# Estimated Fractal Dimension: 1.7055
# Estimated Fractal Dimension: 1.8178
# Estimated Fractal Dimension: 1.3494
# Estimated Fractal Dimension: 1.5054
# Estimated Fractal Dimension: 1.3656
# Estimated Fractal Dimension: 1.8204
# Estimated Fractal Dimension: 1.8093
# Estimated Fractal Dimension: 1.8271
# Estimated Fractal Dimension: 1.4772
# Estimated Fractal Dimension: 1.5496
# Estimated Fractal Dimension: 1.6743
# Estimated Fractal Dimension: 1.6806
# Estimated Fractal Dimension: 1.6568
# Estimated Fractal Dimension: 1.5130
# Estimated Fractal Dimension: 1.6229
# Estimated Fractal Dimension: 1.6086
# Estimated Fractal Dimension: 1.7854
# Estimated Fractal Dimension: 1.9608
# Estimated Fractal Dimension: 1.6780
# Estimated Fractal Dimension: 1.4233
# Estimated Fractal Dimension: 1.6098
# Estimated Fractal Dimension: 1.7327
# Estimated Fractal Dimension: 1.7530
# Estimated Fractal Dimension: 1.7359
# Estimated Fractal Dimension: 1.7342
# Estimated Fractal Dimension: 1.4117
# Estimated Fractal Dimension: 1.8565
# Estimated Fractal Dimension: 1.6668
# Estimated Fractal Dimension: 1.6250
# Estimated Fractal Dimension: 1.6670
# Estimated Fractal Dimension: 1.7582
# Estimated Fractal Dimension: 1.6578
# Estimated Fractal Dimension: 1.6835
# Estimated Fractal Dimension: 1.5778
# Estimated Fractal Dimension: 1.6058
# Estimated Fractal Dimension: 1.7323
# Estimated Fractal Dimension: 1.7987
# Estimated Fractal Dimension: 1.8238
# Estimated Fractal Dimension: 1.5716
# Estimated Fractal Dimension: 1.9426
# Estimated Fractal Dimension: 1.7655
# Estimated Fractal Dimension: 1.7340
# Estimated Fractal Dimension: 1.4575
# Estimated Fractal Dimension: 1.1166
# Estimated Fractal Dimension: 1.9533
# Estimated Fractal Dimension: 1.7949
# Estimated Fractal Dimension: 1.2419
# Estimated Fractal Dimension: 1.7333
# Estimated Fractal Dimension: 1.7613
# Estimated Fractal Dimension: 1.2184
# Estimated Fractal Dimension: 1.8812
# Estimated Fractal Dimension: 1.8040
# Estimated Fractal Dimension: 1.6381
# Estimated Fractal Dimension: 1.5331
# Estimated Fractal Dimension: 1.6163
# Estimated Fractal Dimension: 1.5379
# Estimated Fractal Dimension: 1.5095
# Estimated Fractal Dimension: 1.6773
# Estimated Fractal Dimension: 1.8360
# Estimated Fractal Dimension: 1.3231
# Estimated Fractal Dimension: 1.9020
# Results saved to enzymes_pdb/fractal_dimensions.csv
#    Enzyme Name  Fractal Dimension
# 0       P00760           1.675976
# 1       P49327           2.047670
# 2       P23284           1.646331
# 3       P00918           1.403508
# 4       P53597           1.650328
# ..         ...                ...
# 85      P62877           1.509540
# 86      P00352           1.677307
# 87      P06276           1.836034
# 88      P00374           1.323120
# 89      Q8W3K0           1.901976
#
# [90 rows x 2 columns]

# %%
new_enzymes_fractal_dimension = process_pdb_files('new_enzymes_pdb')
print(new_enzymes_fractal_dimension)
# Out:
# Estimated Fractal Dimension: 1.6990
# Estimated Fractal Dimension: 1.5054
# Estimated Fractal Dimension: 1.6668
# Estimated Fractal Dimension: 1.6743
# Estimated Fractal Dimension: 1.7987
# Estimated Fractal Dimension: 1.4946
# Estimated Fractal Dimension: 1.6163
# Estimated Fractal Dimension: 1.9426
# Estimated Fractal Dimension: 1.5702
# Estimated Fractal Dimension: 1.3416
# Estimated Fractal Dimension: 1.5331
# Estimated Fractal Dimension: 1.5379
# Estimated Fractal Dimension: 1.1916
# Estimated Fractal Dimension: 1.8093
# Estimated Fractal Dimension: 1.3971
# Estimated Fractal Dimension: 1.8271
# Estimated Fractal Dimension: 1.8238
# Estimated Fractal Dimension: 1.7378
# Estimated Fractal Dimension: 1.8565
# Estimated Fractal Dimension: 1.7359
# Estimated Fractal Dimension: 1.6463
# Estimated Fractal Dimension: 1.8360
# Estimated Fractal Dimension: 1.8057
# Estimated Fractal Dimension: 1.8204
# Estimated Fractal Dimension: 2.0477
# Estimated Fractal Dimension: 1.9608
# Estimated Fractal Dimension: 1.8420
# Estimated Fractal Dimension: 1.6503
# Estimated Fractal Dimension: 1.3656
# Estimated Fractal Dimension: 1.1166
# Estimated Fractal Dimension: 1.7342
# Estimated Fractal Dimension: 1.5496
# Estimated Fractal Dimension: 1.6001
# Estimated Fractal Dimension: 1.8040
# Estimated Fractal Dimension: 1.4772
# Estimated Fractal Dimension: 1.6098
# Estimated Fractal Dimension: 1.5851
# Estimated Fractal Dimension: 1.6568
# Estimated Fractal Dimension: 1.6229
# Estimated Fractal Dimension: 1.7530
# Estimated Fractal Dimension: 1.8274
# Estimated Fractal Dimension: 1.7613
# Estimated Fractal Dimension: 1.6760
# Estimated Fractal Dimension: 1.5139
# Estimated Fractal Dimension: 1.9020
# Estimated Fractal Dimension: 1.7340
# Estimated Fractal Dimension: 1.7655
# Estimated Fractal Dimension: 1.7901
# Estimated Fractal Dimension: 1.6742
# Estimated Fractal Dimension: 1.5095
# Estimated Fractal Dimension: 1.6578
# Estimated Fractal Dimension: 1.7582
# Estimated Fractal Dimension: 1.8491
# Estimated Fractal Dimension: 1.6850
# Estimated Fractal Dimension: 1.3494
# Estimated Fractal Dimension: 1.8178
# Estimated Fractal Dimension: 1.7999
# Estimated Fractal Dimension: 1.8812
# Estimated Fractal Dimension: 1.6806
# Estimated Fractal Dimension: 1.4575
# Estimated Fractal Dimension: 1.7949
# Estimated Fractal Dimension: 1.6250
# Estimated Fractal Dimension: 1.7323
# Estimated Fractal Dimension: 1.2419
# Estimated Fractal Dimension: 1.6835
# Estimated Fractal Dimension: 1.4233
# Estimated Fractal Dimension: 1.7238
# Estimated Fractal Dimension: 1.4117
# Estimated Fractal Dimension: 1.5137
# Estimated Fractal Dimension: 1.4035
# Estimated Fractal Dimension: 1.7295
# Estimated Fractal Dimension: 1.6780
# Estimated Fractal Dimension: 1.6058
# Estimated Fractal Dimension: 1.7333
# Estimated Fractal Dimension: 1.6381
# Estimated Fractal Dimension: 1.5778
# Estimated Fractal Dimension: 1.3231
# Estimated Fractal Dimension: 1.7854
# Estimated Fractal Dimension: 1.9533
# Estimated Fractal Dimension: 1.5212
# Estimated Fractal Dimension: 1.2184
# Estimated Fractal Dimension: 1.6670
# Estimated Fractal Dimension: 1.7055
# Estimated Fractal Dimension: 1.9091
# Estimated Fractal Dimension: 1.6773
# Estimated Fractal Dimension: 1.5716
# Estimated Fractal Dimension: 1.7327
# Estimated Fractal Dimension: 1.5130
# Estimated Fractal Dimension: 1.7023
# Results saved to new_enzymes_pdb/fractal_dimensions.csv
#    Enzyme Name  Fractal Dimension
# 0      P00342            1.699040
# 1      P54867            1.505408
# 2      P00791            1.666775
# 3      P04040            1.674253
# 4      P00691            1.798716
# ..         ...                ...
# 84     P00352            1.677307
# 85     P15104            1.571646
# 86     P03956            1.732685
# 87     P00846            1.512995
# 88     P51648            1.702327
#
# [89 rows x 2 columns]

# %%
#View Fractal Dimension values for Enzymes
fractal_dimension_df
# Out:
#    Enzyme Name  Fractal Dimension
# 0       P00760           1.675976
# 1       P49327           2.047670
# 2       P23284           1.646331
# 3       P00918           1.403508
# 4       P53597           1.650328
# ..         ...                ...
# 85      P62877           1.509540
# 86      P00352           1.677307
# 87      P06276           1.836034
# 88      P00374           1.323120
# 89      Q8W3K0           1.901976
#
# [90 rows x 2 columns]

# %% [markdown]
# ### Fractal Dimension For TF

# %%
# Example usage: assuming 'pdb_files' folder contains downloaded PDB files
tf_fractal_dimension_df = process_pdb_files('TFs_pdb')
print(tf_fractal_dimension_df)
# Out:
# Estimated Fractal Dimension: 1.4720
# Estimated Fractal Dimension: 1.4975
# Estimated Fractal Dimension: 1.4916
# Estimated Fractal Dimension: 1.5215
# Estimated Fractal Dimension: 1.6725
# Estimated Fractal Dimension: 1.5519
# Estimated Fractal Dimension: 1.5756
# Estimated Fractal Dimension: 1.6170
# Estimated Fractal Dimension: 1.6158
# Estimated Fractal Dimension: 1.5367
# Estimated Fractal Dimension: 1.6873
# Estimated Fractal Dimension: 1.7185
# Estimated Fractal Dimension: 1.6383
# Estimated Fractal Dimension: 1.5055
# Estimated Fractal Dimension: 1.7778
# Estimated Fractal Dimension: 1.5469
# Estimated Fractal Dimension: 1.5954
# Estimated Fractal Dimension: 1.6929
# Estimated Fractal Dimension: 1.5373
# Estimated Fractal Dimension: 1.6267
# Estimated Fractal Dimension: 1.6586
# Estimated Fractal Dimension: 1.6488
# Estimated Fractal Dimension: 1.4437
# Estimated Fractal Dimension: 1.5416
# Estimated Fractal Dimension: 1.4563
# Estimated Fractal Dimension: 1.5562
# Estimated Fractal Dimension: 1.6261
# Estimated Fractal Dimension: 1.6413
# Estimated Fractal Dimension: 1.5197
# Estimated Fractal Dimension: 1.5966
# Estimated Fractal Dimension: 1.6082
# Estimated Fractal Dimension: 1.4881
# Estimated Fractal Dimension: 1.5946
# Estimated Fractal Dimension: 1.6644
# Estimated Fractal Dimension: 1.4466
# Estimated Fractal Dimension: 1.5755
# Estimated Fractal Dimension: 1.6959
# Estimated Fractal Dimension: 1.5693
# Estimated Fractal Dimension: 1.5827
# Estimated Fractal Dimension: 1.7116
# Estimated Fractal Dimension: 1.5535
# Estimated Fractal Dimension: 1.5681
# Estimated Fractal Dimension: 1.6531
# Estimated Fractal Dimension: 1.4761
# Estimated Fractal Dimension: 1.5657
# Estimated Fractal Dimension: 1.3411
# Estimated Fractal Dimension: 1.4911
# Estimated Fractal Dimension: 1.5121
# Estimated Fractal Dimension: 1.5345
# Estimated Fractal Dimension: 1.7644
# Estimated Fractal Dimension: 1.5904
# Estimated Fractal Dimension: 1.6985
# Estimated Fractal Dimension: 1.6416
# Estimated Fractal Dimension: 1.7307
# Estimated Fractal Dimension: 1.8572
# Estimated Fractal Dimension: 1.5659
# Estimated Fractal Dimension: 1.4570
# Estimated Fractal Dimension: 1.6973
# Estimated Fractal Dimension: 1.5784
# Estimated Fractal Dimension: 1.8205
# Estimated Fractal Dimension: 1.5749
# Estimated Fractal Dimension: 1.6130
# Estimated Fractal Dimension: 1.6407
# Estimated Fractal Dimension: 1.5569
# Estimated Fractal Dimension: 1.4852
# Estimated Fractal Dimension: 1.4734
# Estimated Fractal Dimension: 1.5221
# Estimated Fractal Dimension: 1.7312
# Estimated Fractal Dimension: 1.5937
# Estimated Fractal Dimension: 1.7138
# Estimated Fractal Dimension: 1.6378
# Estimated Fractal Dimension: 1.5960
# Estimated Fractal Dimension: 1.5776
# Estimated Fractal Dimension: 1.5321
# Estimated Fractal Dimension: 1.5021
# Estimated Fractal Dimension: 1.6382
# Estimated Fractal Dimension: 1.6875
# Estimated Fractal Dimension: 1.4084
# Estimated Fractal Dimension: 1.7803
# Estimated Fractal Dimension: 1.8709
# Estimated Fractal Dimension: 1.7125
# Estimated Fractal Dimension: 1.6551
# Estimated Fractal Dimension: 1.6422
# Estimated Fractal Dimension: 1.6611
# Estimated Fractal Dimension: 1.5106
# Estimated Fractal Dimension: 1.6100
# Estimated Fractal Dimension: 1.5312
# Estimated Fractal Dimension: 1.5545
# Estimated Fractal Dimension: 1.5988
# Estimated Fractal Dimension: 1.6628
# Estimated Fractal Dimension: 1.4878
# Estimated Fractal Dimension: 1.6257
# Estimated Fractal Dimension: 1.4966
# Estimated Fractal Dimension: 1.3595
# Estimated Fractal Dimension: 1.4867
# Results saved to TFs_pdb/fractal_dimensions.csv
#    Enzyme Name  Fractal Dimension
# 0       P15976           1.472019
# 1       P05412           1.497539
# 2       P17275           1.491633
# 3       Q01860           1.521528
# 4       Q13485           1.672467
# ..         ...                ...
# 90      Q06413           1.487791
# 91      P22736           1.625714
# 92      P16220           1.496568
# 93      Q15672           1.359496
# 94      P48431           1.486743
#
# [95 rows x 2 columns]

# %%
# 90 Tfs
new_tf_fractal_dimension_df = process_pdb_files('new_TFs_pdb')
print(new_tf_fractal_dimension_df)
# Out:
# Estimated Fractal Dimension: 1.5345
# Estimated Fractal Dimension: 1.5657
# Estimated Fractal Dimension: 1.5545
# Estimated Fractal Dimension: 1.6267
# Estimated Fractal Dimension: 1.6531
# Estimated Fractal Dimension: 1.4852
# Estimated Fractal Dimension: 1.6170
# Estimated Fractal Dimension: 1.7185
# Estimated Fractal Dimension: 1.5693
# Estimated Fractal Dimension: 1.8709
# Estimated Fractal Dimension: 1.5197
# Estimated Fractal Dimension: 1.6551
# Estimated Fractal Dimension: 1.4867
# Estimated Fractal Dimension: 1.6628
# Estimated Fractal Dimension: 1.8572
# Estimated Fractal Dimension: 1.6929
# Estimated Fractal Dimension: 1.6383
# Estimated Fractal Dimension: 1.5755
# Estimated Fractal Dimension: 1.4734
# Estimated Fractal Dimension: 1.5535
# Estimated Fractal Dimension: 1.5988
# Estimated Fractal Dimension: 1.7116
# Estimated Fractal Dimension: 1.6644
# Estimated Fractal Dimension: 1.5659
# Estimated Fractal Dimension: 1.4878
# Estimated Fractal Dimension: 1.6378
# Estimated Fractal Dimension: 1.7803
# Estimated Fractal Dimension: 1.6261
# Estimated Fractal Dimension: 1.6973
# Estimated Fractal Dimension: 1.7778
# Estimated Fractal Dimension: 1.4084
# Estimated Fractal Dimension: 1.5776
# Estimated Fractal Dimension: 1.5756
# Estimated Fractal Dimension: 1.4570
# Estimated Fractal Dimension: 1.5416
# Estimated Fractal Dimension: 1.5321
# Estimated Fractal Dimension: 1.7644
# Estimated Fractal Dimension: 1.6158
# Estimated Fractal Dimension: 1.5937
# Estimated Fractal Dimension: 1.6413
# Estimated Fractal Dimension: 1.7138
# Estimated Fractal Dimension: 1.6416
# Estimated Fractal Dimension: 1.6488
# Estimated Fractal Dimension: 1.5966
# Estimated Fractal Dimension: 1.5749
# Estimated Fractal Dimension: 1.6611
# Estimated Fractal Dimension: 1.5827
# Estimated Fractal Dimension: 1.5569
# Estimated Fractal Dimension: 1.4916
# Estimated Fractal Dimension: 1.6407
# Estimated Fractal Dimension: 1.6873
# Estimated Fractal Dimension: 1.5946
# Estimated Fractal Dimension: 1.6959
# Estimated Fractal Dimension: 1.6130
# Estimated Fractal Dimension: 1.8205
# Estimated Fractal Dimension: 1.3595
# Estimated Fractal Dimension: 1.6257
# Estimated Fractal Dimension: 1.5562
# Estimated Fractal Dimension: 1.5021
# Estimated Fractal Dimension: 1.7312
# Estimated Fractal Dimension: 1.6100
# Estimated Fractal Dimension: 1.6985
# Estimated Fractal Dimension: 1.5221
# Estimated Fractal Dimension: 1.5055
# Estimated Fractal Dimension: 1.6082
# Estimated Fractal Dimension: 1.5784
# Estimated Fractal Dimension: 1.5519
# Estimated Fractal Dimension: 1.4761
# Estimated Fractal Dimension: 1.6422
# Estimated Fractal Dimension: 1.6875
# Estimated Fractal Dimension: 1.5954
# Estimated Fractal Dimension: 1.5106
# Estimated Fractal Dimension: 1.4720
# Estimated Fractal Dimension: 1.5681
# Estimated Fractal Dimension: 1.3411
# Estimated Fractal Dimension: 1.6382
# Estimated Fractal Dimension: 1.4563
# Estimated Fractal Dimension: 1.5960
# Estimated Fractal Dimension: 1.4911
# Estimated Fractal Dimension: 1.6586
# Estimated Fractal Dimension: 1.4966
# Estimated Fractal Dimension: 1.4437
# Estimated Fractal Dimension: 1.5373
# Estimated Fractal Dimension: 1.4466
# Estimated Fractal Dimension: 1.6725
# Estimated Fractal Dimension: 1.5121
# Estimated Fractal Dimension: 1.7125
# Estimated Fractal Dimension: 1.4975
# Estimated Fractal Dimension: 1.5312
# Results saved to new_TFs_pdb/fractal_dimensions.csv
#    Enzyme Name  Fractal Dimension
# 0      P01106            1.534458
# 1      O43524            1.565665
# 2      P15923            1.554529
# 3      Q08050            1.626657
# 4      P08047            1.653096
# ..         ...                ...
# 84     Q13485            1.672467
# 85     P49715            1.512132
# 86     P37275            1.712454
# 87     P05412            1.497539
# 88     P48436            1.531153
#
# [89 rows x 2 columns]

# %%
enzymes_90
# Out:
#    Enzyme_ID  Shannon Entropy  Number of Transitions
# 0    P00813          1.219976                     62
# 1    P00439          1.424472                     77
# 2    P34897          1.261891                     62
# 3    P21912          1.477573                     39
# 4    P47989          1.419869                    206
# ..       ...              ...                    ...
# 85   P06744          1.356219                     77
# 86   P49247          1.513133                     47
# 87   P00734          1.446652                     95
# 88   P00700          1.584585                     24
# 89   P03956          1.503592                     74
#
# [90 rows x 3 columns]

# %%
# Perform a left join on the two DataFrames
updated_file_enzymes = pd.merge(enzymes_90, new_enzymes_fractal_dimension, how='left', left_on='Enzyme_ID', right_on='Enzyme Name')
updated_file_enzymes
# Out:
#    Enzyme_ID  Shannon Entropy  Number of Transitions Enzyme Name  \
# 0    P00813          1.219976                     62     P00813
# 1    P00439          1.424472                     77     P00439
# 2    P34897          1.261891                     62     P34897
# 3    P21912          1.477573                     39     P21912
# 4    P47989          1.419869                    206     P47989
# ..       ...              ...                    ...         ...
# 85   P06744          1.356219                     77     P06744
# 86   P49247          1.513133                     47     P49247
# 87   P00734          1.446652                     95     P00734
# 88   P00700          1.584585                     24     P00700
# 89   P03956          1.503592                     74     P03956
#
#     Fractal Dimension
# 0            1.513691
# 1            1.656789
# 2            1.734157
# 3            1.533105
# 4            1.909126
# ..                ...
# 85           1.680604
# 86           1.577839
# 87           1.799924
# 88           1.241940
# 89           1.732685
#
# [90 rows x 5 columns]

# %%
# Dropping the 'Enzyme Name' column
updated_file_enzymes.drop(columns=['Enzyme Name'], inplace=True)

file_path = "/home/marshal/protonotebook/Management and analysis of Biological and Medical Data/updated_file_enzymes.csv"

# Save the DataFrame to a CSV file
updated_file_enzymes.to_csv(file_path, index=False)

# %% [markdown]
# ## Transcriptor Factors

# %%
new_tf_fractal_dimension_df
# Out:
#    Enzyme Name  Fractal Dimension
# 0      P01106            1.534458
# 1      O43524            1.565665
# 2      P15923            1.554529
# 3      Q08050            1.626657
# 4      P08047            1.653096
# ..         ...                ...
# 84     Q13485            1.672467
# 85     P49715            1.512132
# 86     P37275            1.712454
# 87     P05412            1.497539
# 88     P48436            1.531153
#
# [89 rows x 2 columns]

# %%
# Check for NaN values in the DataFrame
nan_count = new_tf_fractal_dimension_df.isna().sum()
nan_count
# Out:
# Enzyme Name          0
# Fractal Dimension    0
# dtype: int64

# %%
# Perform a left join on the two DataFrames
updated_file_tfs = pd.merge(tf_90, new_tf_fractal_dimension_df, how='left', left_on='TF_ID', right_on='Enzyme Name')
updated_file_tfs
# Out:
#        TF_ID  Shannon Entropy  Number of Transitions Enzyme Name  \
# 0    P22736          1.400063                     76     P22736
# 1    Q9H334          1.340514                     70     Q9H334
# 2    P48436          1.480286                     68     P48436
# 3    P28347          1.358966                     64     P28347
# 4    Q06330          1.494394                     75     Q06330
# ..       ...              ...                    ...         ...
# 85   O15350          1.514592                     96     O15350
# 86   P16220          1.335435                     42     P16220
# 87   Q15672          1.222014                     11     Q15672
# 88   P43694          1.473598                     65     P43694
# 89   P08047          1.578222                    120     P08047
#
#     Fractal Dimension
# 0            1.625714
# 1            1.658552
# 2            1.531153
# 3            1.640730
# 4            1.713782
# ..                ...
# 85           1.641319
# 86           1.496568
# 87           1.359496
# 88           1.502082
# 89           1.653096
#
# [90 rows x 5 columns]

# %%
# Check for NaN values in the DataFrame
nan_count_2 = updated_file_tfs.isna().sum()
nan_count_2
# Out:
# TF_ID                    0
# Shannon Entropy          0
# Number of Transitions    0
# Fractal Dimension        1
# dtype: int64

# %%
# Dropping the 'Enzyme Name' column
updated_file_tfs.drop(columns=['Enzyme Name'], inplace=True)

file_path = "/home/marshal/protonotebook/Management and analysis of Biological and Medical Data/updated_file_tfs.csv"

# Save the DataFrame to a CSV file
updated_file_tfs.to_csv(file_path, index=False)
