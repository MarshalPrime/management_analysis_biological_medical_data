# %% [markdown]
# # Comparing both Human and Mouse networks

# %% [markdown]
# #### **Human**
#
# Here I have used Homo sapiens as species, scRNA-seq as Data type, Blood as Tissue type,10X Genomics as Platform, Primary cell as Biosample type and the sample number is "sample_1_h_100".
#
# Under these filterations, few samples were available.And we will be discovering the charaterics in this single-cell as a network.

# %% [markdown]
# #### **Mouse**
#
# Here I have used Mus musculus as species, scRNA-seq as Data type, Bone marrow as Tissue type,10X Genomics as Platform, Primary cell as Biosample type and the sample number is "sample_1_m_170".
#
# Under these filterations, few samples were available.And we will be discovering the charaterics in this single-cell as a network.

# %% [markdown]
# ## Import the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import plotly.graph_objects as go

# %% [markdown]
# ## Load the both dataframes

# %%
# Load mouse network data
mouse_file_path = r"E:\Narmada\download-sample_1_m_170-nonredundant_GRN.txt"
mouse_data = pd.read_csv(mouse_file_path, sep="\t")

# Load human network data
human_file_path = r"E:\Narmada\download-sample_1_h_100-nonredundant_GRN.txt"
human_data = pd.read_csv(human_file_path, sep="\t")

# %% [markdown]
# ## Create Graphs

# %%
# Create mouse network graph
G_mouse = nx.from_pandas_edgelist(mouse_data, source='TF', target='target', create_using=nx.DiGraph())

# Create human network graph
G_human = nx.from_pandas_edgelist(human_data, source='TF', target='target', create_using=nx.DiGraph())

# %% [markdown]
# ## Visualize Networks

# %% [markdown]
# ## Reducing the sample size of both samples

# %%
# Randomly sample a subset of the data- human
sampled_data_human = human_data.sample(frac=0.1, random_state=42)  # Adjust frac to reduce the number of data points

# Randomly sample a subset of the data- human
sampled_data_mouse = mouse_data.sample(frac=0.1, random_state=42)  # Adjust frac to reduce the number of data points

# %% [markdown]
# ### Create Graphs

# %%
# Create mouse network graph
G1_mouse = nx.from_pandas_edgelist(sampled_data_mouse, source='TF', target='target', create_using=nx.DiGraph())

# Create human network graph
G1_human = nx.from_pandas_edgelist(sampled_data_human, source='TF', target='target', create_using=nx.DiGraph())

# %% [markdown]
# ## Visualize Networks

# %%
def create_network_figure(G, title):
    pos = nx.spring_layout(G)
    
    edge_trace = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        trace = go.Scatter(
            x=[x0, x1, None],
            y=[y0, y1, None],
            line=dict(width=0.5, color='#888'),
            hoverinfo='none',
            mode='lines')
        edge_trace.append(trace)

    node_trace = go.Scatter(
        x=[],
        y=[],
        text=[],
        mode='markers+text',
        textposition="top center",
        hoverinfo='text',
        marker=dict(
            showscale=True,
            colorscale='Purples',
            size=10,
            colorbar=dict(
                thickness=15,
                title='Node Connections',
                xanchor='left',
                titleside='right'
            ),
        )
    )

    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        node_trace['text'] += tuple([node])

    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(
                        title=f'<br>{title}',
                        titlefont_size=16,
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20,l=5,r=5,t=40),
                        annotations=[dict(
                            text=f"{title}",
                            showarrow=False,
                            xref="paper", yref="paper",
                            x=0.005, y=-0.002 )],
                        xaxis=dict(showgrid=False, zeroline=False),
                        yaxis=dict(showgrid=False, zeroline=False))
                    )
    return fig

# Create figures for both networks
fig1_mouse = create_network_figure(G1_mouse, "Mouse Network for reduced sample size")
fig1_human = create_network_figure(G1_human, "Human Network for reduced sample size")

# Show figures
fig1_mouse.show()
fig1_human.show()

# %% [markdown]
# # Reducing the sample size upto 100 datapoints of both samples

# %%
# Randomly sample 100 rows from the data - mouse
sampled_data_mouse2 = mouse_data.sample(n=100, random_state=42)

# Randomly sample 100 rows from the data - mouse
sampled_data_human2 = human_data.sample(n=100, random_state=42)

# %% [markdown]
# ### Create Graphs

# %%
# Create mouse network graph
G2_mouse = nx.from_pandas_edgelist(sampled_data_mouse2, source='TF', target='target', create_using=nx.DiGraph())

# Create human network graph
G2_human = nx.from_pandas_edgelist(sampled_data_human2, source='TF', target='target', create_using=nx.DiGraph())

# %% [markdown]
# ### Visualize Networks

# %%
def create_network_figure(G, title):
    pos = nx.spring_layout(G)
    
    edge_trace = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        trace = go.Scatter(
            x=[x0, x1, None],
            y=[y0, y1, None],
            line=dict(width=0.5, color='#888'),
            hoverinfo='none',
            mode='lines')
        edge_trace.append(trace)

    node_trace = go.Scatter(
        x=[],
        y=[],
        text=[],
        mode='markers+text',
        textposition="top center",
        hoverinfo='text',
        marker=dict(
            showscale=True,
            colorscale='Purples',
            size=10,
            colorbar=dict(
                thickness=15,
                title='Node Connections',
                xanchor='left',
                titleside='right'
            ),
        )
    )

    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        node_trace['text'] += tuple([node])

    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(
                        title=f'<br>{title}',
                        titlefont_size=16,
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20,l=5,r=5,t=40),
                        annotations=[dict(
                            text=f"{title}",
                            showarrow=False,
                            xref="paper", yref="paper",
                            x=0.005, y=-0.002 )],
                        xaxis=dict(showgrid=False, zeroline=False),
                        yaxis=dict(showgrid=False, zeroline=False))
                    )
    return fig

# Create figures for both networks
fig2_mouse = create_network_figure(G2_mouse, "Mouse Network for reduced sample size to 100 datapoints")
fig2_human = create_network_figure(G2_human, "Human Network for reduced sample size to 100 datapoints")

# Show figures
fig2_mouse.show()
fig2_human.show()

# %% [markdown]
# # Combine the both networks

# %%
def create_combined_network_figure(G_mouse, G_human):
    pos_mouse = nx.spring_layout(G_mouse)
    pos_human = nx.spring_layout(G_human)
    
    edge_trace_mouse = []
    for edge in G_mouse.edges(data=True):
        x0, y0 = pos_mouse[edge[0]]
        x1, y1 = pos_mouse[edge[1]]
        trace = go.Scatter(
            x=[x0, x1, None],
            y=[y0, y1, None],
            line=dict(width=0.5, color='blue'),  # Mouse edges in blue
            hoverinfo='none',
            mode='lines')
        edge_trace_mouse.append(trace)

    node_trace_mouse = go.Scatter(
        x=[],
        y=[],
        text=[],
        mode='markers+text',
        textposition="top center",
        hoverinfo='text',
        marker=dict(
            showscale=True,
            colorscale='Blues',
            size=10,
            colorbar=dict(
                thickness=15,
                title='Mouse Node Connections',
                xanchor='left',
                titleside='right'
            ),
        )
    )

    for node in G_mouse.nodes():
        x, y = pos_mouse[node]
        node_trace_mouse['x'] += tuple([x])
        node_trace_mouse['y'] += tuple([y])
        node_trace_mouse['text'] += tuple([node])

    edge_trace_human = []
    for edge in G_human.edges(data=True):
        x0, y0 = pos_human[edge[0]]
        x1, y1 = pos_human[edge[1]]
        trace = go.Scatter(
            x=[x0, x1, None],
            y=[y0, y1, None],
            line=dict(width=0.5, color='red'),  # Human edges in red
            hoverinfo='none',
            mode='lines')
        edge_trace_human.append(trace)

    node_trace_human = go.Scatter(
        x=[],
        y=[],
        text=[],
        mode='markers+text',
        textposition="top center",
        hoverinfo='text',
        marker=dict(
            showscale=True,
            colorscale='Reds',
            size=10,
            colorbar=dict(
                thickness=15,
                title='Human Node Connections',
                xanchor='left',
                titleside='right'
            ),
        )
    )

    for node in G_human.nodes():
        x, y = pos_human[node]
        node_trace_human['x'] += tuple([x])
        node_trace_human['y'] += tuple([y])
        node_trace_human['text'] += tuple([node])

    fig = go.Figure(data=edge_trace_mouse + [node_trace_mouse] + edge_trace_human + [node_trace_human],
                    layout=go.Layout(
                        title='<br>Combined Mouse and Human Network Graph',
                        titlefont_size=16,
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20,l=5,r=5,t=40),
                        annotations=[dict(
                            text="Combined Mouse and Human Network Graph using Plotly",
                            showarrow=False,
                            xref="paper", yref="paper",
                            x=0.005, y=-0.002 )],
                        xaxis=dict(showgrid=False, zeroline=False),
                        yaxis=dict(showgrid=False, zeroline=False))
                    )
    return fig

# Create combined figure for both networks
fig_combined = create_combined_network_figure(G2_mouse, G2_human)

# Show combined figure
fig_combined.show()

# %%
def create_combined_network_figure(G_mouse, G_human):
    pos_mouse = nx.spring_layout(G_mouse)
    pos_human = nx.spring_layout(G_human)
    
    edge_trace_mouse = []
    for edge in G_mouse.edges(data=True):
        x0, y0 = pos_mouse[edge[0]]
        x1, y1 = pos_mouse[edge[1]]
        trace = go.Scatter(
            x=[x0, x1, None],
            y=[y0, y1, None],
            line=dict(width=0.5, color='blue'),  # Mouse edges in blue
            hoverinfo='none',
            mode='lines',
            name='Mouse Edge')
        edge_trace_mouse.append(trace)

    node_trace_mouse = go.Scatter(
        x=[],
        y=[],
        text=[],
        mode='markers+text',
        textposition="top center",
        hoverinfo='text',
        marker=dict(
            showscale=True,
            colorscale='Blues',
            size=10,
            colorbar=dict(
                thickness=15,
                title='Mouse Node Connections',
                xanchor='left',
                titleside='right',
                yanchor='top',
                y=1
            ),
        ),
        name='Mouse Node'
    )

    for node in G_mouse.nodes():
        x, y = pos_mouse[node]
        node_trace_mouse['x'] += tuple([x])
        node_trace_mouse['y'] += tuple([y])
        node_trace_mouse['text'] += tuple([node])

    edge_trace_human = []
    for edge in G_human.edges(data=True):
        x0, y0 = pos_human[edge[0]]
        x1, y1 = pos_human[edge[1]]
        trace = go.Scatter(
            x=[x0, x1, None],
            y=[y0, y1, None],
            line=dict(width=0.5, color='red'),  # Human edges in red
            hoverinfo='none',
            mode='lines',
            name='Human Edge')
        edge_trace_human.append(trace)

    node_trace_human = go.Scatter(
        x=[],
        y=[],
        text=[],
        mode='markers+text',
        textposition="top center",
        hoverinfo='text',
        marker=dict(
            showscale=True,
            colorscale='Reds',
            size=10,
            colorbar=dict(
                thickness=15,
                title='Human Node Connections',
                xanchor='left',
                titleside='right',
                yanchor='top',
                y=0.5
            ),
        ),
        name='Human Node'
    )

    for node in G_human.nodes():
        x, y = pos_human[node]
        node_trace_human['x'] += tuple([x])
        node_trace_human['y'] += tuple([y])
        node_trace_human['text'] += tuple([node])

    fig = go.Figure(data=edge_trace_mouse + [node_trace_mouse] + edge_trace_human + [node_trace_human],
                    layout=go.Layout(
                        title='<br>Combined Mouse and Human Network Graph',
                        titlefont_size=16,
                        showlegend=True,
                        legend=dict(x=1.05, y=1),  # Move legend to the right side of the plot
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=200, t=20),  # Increase right margin to accommodate colorbars
                        annotations=[
                            dict(
                                text="Mouse Network (Blue)",
                                showarrow=False,
                                xref="paper", yref="paper",
                                x=0.85, y=1.05,
                                font=dict(color="blue", size=12)
                            ),
                            dict(
                                text="Human Network (Red)",
                                showarrow=False,
                                xref="paper", yref="paper",
                                x=0.85, y=1.00,
                                font=dict(color="red", size=12)
                            )
                        ],
                        xaxis=dict(showgrid=False, zeroline=False),
                        yaxis=dict(showgrid=False, zeroline=False),
                        width=1200,  # Increase figure width
                        height=800   # Increase figure height
                    ))
    return fig

# Create combined figure for both networks
fig_combined = create_combined_network_figure(G2_mouse, G2_human)

# Show combined figure
fig_combined.show()
